# %% [markdown]
# <a href="https://colab.research.google.com/github/Mizuko821/master_thesis/blob/main/%E5%AE%9F%E9%A8%932_%E3%82%B7%E3%83%B3%E3%82%B0%E3%83%AB%E3%82%BF%E3%82%B9%E3%82%AF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##環境
# Google Colabratory
# ランタイム:GPU（V100）を使用

# %%
# !pip install transformers torch
# !pip install accelerate -U
# !pip install fugashi ipadic

# %%
import os
import json
import re
import pandas as pd
from transformers import AutoTokenizer, BertTokenizer, BertPreTrainedModel, BertModel, AdamW, get_linear_schedule_with_warmup, TrainingArguments
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split, RandomSampler, SequentialSampler
from torch.optim import AdamW
import matplotlib.pyplot as plt
from torch import nn
from transformers.modeling_outputs import SequenceClassifierOutput
from sklearn.manifold import TSNE
import numpy as np
from typing import Tuple
from sklearn.metrics import confusion_matrix
import seaborn as sns
import random
from sklearn.metrics import f1_score, classification_report

# %%
# デバイスの設定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def set_seed(seed_value):
    """Set seed for reproducibility.
    """
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)

set_seed(42)

# %%
#Twitterデータセットへのファイルのパスを設定する
tweet_path = "パスを入力する"

# %%
# CSVファイルを読み込む
df = pd.read_csv(tweet_path)
df.head()
# Out:
#     target                                           sentence  polarity
# 0  インボイス制度  フリーランスや、フリーランスへの親近感が強い方が多めのタイムライン構成なので、インボイス制度...  positive
# 1  インボイス制度  個人的な意見だが徴税制度がすべて悪とは思ってない。インボイス制度はわけのわからん軽減率より分...  positive
# 2  インボイス制度  こんな状況にもかかわらずインボイス制度賛成というのは理解が難しいです。大企業ではなく、個人事...  negative
# 3  インボイス制度  インボイス制度はそもそも反対なのだが、まず前提として、あらゆる手続きの負荷は簡便であることを...  negative
# 4  インボイス制度  インボイス制度何が何でも反対！の人が多いけど消費税払ってるちっさい会社の立場としてはなんでそ...  positive

# %%
# 改行コードを削除
df['sentence'] = df['sentence'].apply(lambda x: re.sub(r'\r?\n', '', x))
df['sentence']
# Out:
# 0      フリーランスや、フリーランスへの親近感が強い方が多めのタイムライン構成なので、インボイス制度...
# 1      個人的な意見だが徴税制度がすべて悪とは思ってない。インボイス制度はわけのわからん軽減率より分...
# 2      こんな状況にもかかわらずインボイス制度賛成というのは理解が難しいです。大企業ではなく、個人事...
# 3      インボイス制度はそもそも反対なのだが、まず前提として、あらゆる手続きの負荷は簡便であることを...
# 4      インボイス制度何が何でも反対！の人が多いけど消費税払ってるちっさい会社の立場としてはなんでそ...
#                              ...
# 140    選択的夫婦別姓のメリットは・姓を理由として結婚しなかった人たちが結婚に踏み切れる・親子での姓...
# 141    そもそも「選択的夫婦別姓が“ないから”結婚できない夫婦」はいても、「選択的夫婦別姓“あるから...
# 142    選択的夫婦別姓ってノーリスクでリターンしかないと思ってたけど、別姓にしなかった場合に「同姓に...
# 143    選択的夫婦別姓の問題点について考えてみたが、戸籍とかその辺の法律改正含むし、大混乱になる可能...
# 144    「選択的夫婦別姓」を私が素直に賛成できないのは、それで生まれた子ども自身が「選択するわけでは...
# Name: sentence, Length: 145, dtype: object

# %%
# 極性ラベルを数字にマッピング
label_mapping = {"positive": 0, "neutral": 1, "negative": 2}
df["pol_labels"] = df["polarity"].map(label_mapping)

# %%
class TextDataset(Dataset):
    def __init__(self, target, sentence, pol_labels):
        self.target = target.values
        self.sentence = sentence.values
        self.pol_labels = pol_labels.values

    def __len__(self):
        return len(self.target)

    def __getitem__(self, idx):
        return self.target[idx], self.sentence[idx], torch.tensor(self.pol_labels[idx], dtype=torch.long)

# %%
# データセットを作成
tweetset = TextDataset(pd.Series(df["target"]), pd.Series(df["sentence"]), pd.Series(df["pol_labels"]))

# %%
# DataLoaderのパラメータ設定
batch_size = 16
num_pol_labels = 3


# テスト用データローダー
tweet_dataloader = DataLoader(
    tweetset,
    batch_size=batch_size
)

# %% [markdown]
# ### モデル実装（極性分類+カテゴリー分類）

# %%
class SingleTaskModel(BertPreTrainedModel):

    def __init__(self, config):
        super().__init__(config)
        self.num_labels = config.num_labels
        self.config = config

        self.bert = BertModel(config)

        classifier_dropout = (
            config.classifier_dropout if config.classifier_dropout is not None \
                else config.hidden_dropout_prob
        )

        # 極性分類用のネットワーク
        self.pol_dropout = nn.Dropout(classifier_dropout)
        self.pol_layer1 = nn.Linear(config.hidden_size, config.hidden_size)
        self.pol_activation1 = nn.ReLU()
        self.pol_layer2 = nn.Linear(config.hidden_size, config.hidden_size)
        self.pol_activation2 = nn.ReLU()
        self.pol_classifier = nn.Linear(config.hidden_size, config.num_labels)

        self.post_init()

    def forward(self, input_ids=None, attention_mask=None, token_type_ids=None, pol_labels=None, **kwargs):
        outputs = self.bert(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids, **kwargs)
        pooled_output = outputs[1]
        pooled_output = self.pol_dropout(pooled_output)

        # 感情分類のロジット
        pol_out = self.pol_activation1(self.pol_layer1(pooled_output))
        pol_out = self.pol_activation2(self.pol_layer2(pol_out))
        pol_logits = self.pol_classifier(pol_out)

        return {
            "pol_logits": pol_logits,
            "hidden_states": outputs.hidden_states,
            "attentions": outputs.attentions,
            "pooler_output":outputs.pooler_output
        }

# %%
# 1. モデルアーキテクチャの初期化
#tokenizerとmodelのインスタンス化
modelName = 'cl-tohoku/bert-base-japanese-whole-word-masking'
tokenizer =  AutoTokenizer.from_pretrained(modelName)
model = SingleTaskModel.from_pretrained(modelName, num_labels=num_pol_labels).to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/110 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/479 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/258k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of SingleTaskModel were not initialized from the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking and are newly initialized: ['pol_layer2.weight', 'pol_classifier.weight', 'pol_classifier.bias', 'pol_layer1.weight', 'pol_layer1.bias', 'pol_layer2.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#保存された状態辞書のロード
model_path = "実験1で学習したモデルへのパスを入力する"

model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
# モデルを評価モードに設定
model.eval()

total_loss, pol_total_correct, total_samples = 0, 0, len(tweetset)
pol_predictions, pol_labels_list = [], []

pooler_output = []
pol_labels_list = []

# 誤った予測とその詳細を記録するリスト
incorrect_polarity_samples = []

loss_fct = nn.CrossEntropyLoss()

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(tweet_dataloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()
        pooler_output.append(pred["pooler_output"])

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })


avg_loss = total_loss / len(tweet_dataloader)
pol_accuracy = pol_total_correct / total_samples

# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')

# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 2.3589
# Test Pol Accuracy: 0.4000, F1: 0.3998
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40        51
#            1       0.36      0.46      0.40        48
#            2       0.38      0.41      0.40        46
#
#     accuracy                           0.40       145
#    macro avg       0.41      0.40      0.40       145
# weighted avg       0.42      0.40      0.40       145

# %% [markdown]
# ### Counfusion Matrix

# %%
# Confusion Matrixの計算
polarity_cm = confusion_matrix(pol_labels_list, pol_predictions)

# %%
# Confusion Matrixの計算後...
plt.figure(figsize=(6, 6))  # サイズ調整

sns.heatmap(polarity_cm, annot=True, fmt="", cmap='Blues', cbar_kws={"shrink": 0.75}, annot_kws={"size": 16})
plt.xlabel('Predicted Polarity', fontsize=20)
plt.ylabel('True Polarity', fontsize=20)
plt.title('Polarity Confusion Matrix', fontsize=20)
plt.tight_layout()
plt.xticks(rotation=90, fontsize=20)
plt.yticks(rotation=0, fontsize=20)
plt.show()

# %% [markdown]
# ### 不正解の事例

# %%
len(incorrect_polarity_samples)
# Out:
# 87

# %%
incorrect_polarity_samples
# Out:
# [{'batch_index': 0,
#   'sample_index': 0,
#   'target': 'インボイス制度',
#   'sentence': 'フリーランスや、フリーランスへの親近感が強い方が多めのタイムライン構成なので、インボイス制度に反対する意見をよく見るんだけど、一般企業の経理職を長くやってきた経験からするとインボイス制度わりと賛成なんですよね。',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 2,
#   'target': 'インボイス制度',
#   'sentence': 'こんな状況にもかかわらずインボイス制度賛成というのは理解が難しいです。大企業ではなく、個人事業主達の税負担が増え、経費精算が煩わしくなる上に、こんな金の使い方をする現与党に米櫃に手を突っ込ませるのは意味がわからない。「私は税理士雇えるから大丈夫」というレベルの問題じゃないのに。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 3,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度はそもそも反対なのだが、まず前提として、あらゆる手続きの負荷は簡便であることを目指すべき、なぜなら多くの人類は事務能力がそれほどないから、事務能力は結構特殊能力、人間のリソースは限られている、仕組みで限られたリソースの可動域を広げるべき、と思っているのが少数なのか？',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 4,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度何が何でも反対！の人が多いけど消費税払ってるちっさい会社の立場としてはなんでそれ利益になんねん、と思ってるから賛成です。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 7,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度の問題を所謂左翼・リベラル運動に結びつけたがる人が賛成派にも反対派にもいるけど、そういうのにはついていけないしインボイスとは関係がない。インボイスの問題はその他の政治イデオロギーとは関係のない、あくまでも事業者の税負担・事務負担と生活・経営の問題でしかない。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 11,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度さっさと廃止しろよ。インボイス廃止反対派の人たち何が良くて賛成してんの？',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 13,
#   'target': 'インボイス制度',
#   'sentence': '事業者支援、インボイス制度、消費税そのもの論点全てごっちゃにするの辞めてもらっていいですかのお気持ち',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 14,
#   'target': 'インボイス制度',
#   'sentence': '個人事業主、フリーランスに負担のかかる「インボイス制度」。いまいちよく分からないので反対とか賛成もできないが。どうなんだろ？',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 15,
#   'target': 'インボイス制度',
#   'sentence': 'やっぱ、どう贔屓目に見ても、インボイス制度は無茶過ぎる。軽減税率の厳格運用×益税をなくす×消費税引き上げの準備×デジタルインボイス加速、と国のメリットを一度に取りに来ている。普通は、事務負担増しには減税をかけ合わせたりするものなんだけど、これじゃ誰も賛成できないよ。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 0,
#   'target': 'インボイス制度',
#   'sentence': 'またインボイスのひでぇ記事が出てるなぁ…施行されて業界が歪むようなら、そもそもの業界体質の方が問題だと思うけど。。。僕は基本的にはインボイス制度賛成派です。これ以上重大な因子になる前に解決しておくべき。ただ使いやすい形にはしてほしい。クレカとスマホの履歴でなんとかしてくれ。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 1,
#   'sample_index': 2,
#   'target': 'インボイス制度',
#   'sentence': 'てかインボイス制度に反対してる人達って水増し請求とか実利益を計上してないタイプの小規模事業主も多いだろうなそもそも弱い物いじめとかじゃなくて、計上関連をより正確かつ公平な取引を目指してる意味では俺は賛成だわそれが嫌なら事業辞めて雇用される選択もあるんだし',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 1,
#   'sample_index': 5,
#   'target': 'インボイス制度',
#   'sentence': 'すごく大変だけれどインボイス制度賛成派です。どんな特例も短期で切り上げるべき。この流れの後に電子帳簿保存法に移行する企業も増えると思う。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 1,
#   'sample_index': 6,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度はどう見ても免税事業者つぶし…少しでもふんだくろうという意志しか感じないし、増税の上にっていうのが…国が国のためだけに税金巻き上げている感じが嫌だな…国民に還元される未来が見えないし、そんな負担ばかり強いるから反対するんだよ…。賛成派って本当に世の中みえてんのかね',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 7,
#   'target': 'テレワーク',
#   'sentence': 'テレワークは確かに楽です。通勤時間が0になるのは非常に大きいです。しかし、自宅という、全てから開放される安全地帯が仕事に侵食されるというデメリットもあります。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 8,
#   'target': 'テレワーク',
#   'sentence': 'テレワーク、完全になくなったわけではないけど出社推奨されてる感が…。テレワークにデメリット(業務遅延とかコミュニケーション不足とか…)があるからみたいなんですが…おかしいでしょ。その課題解決する方法が本当に出社することなのか？',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 1,
#   'sample_index': 9,
#   'target': 'テレワーク',
#   'sentence': '私はテレワークは賛成ではない。テレワークだと、職員が、仕事しないで遊んでいてもバレない場合があるような気がします。結果は大事だが、勤務態度も大事です。もちろん、コロナが流行っているうちは、テレワークになるのは仕方ないです。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 11,
#   'target': 'テレワーク',
#   'sentence': 'テレワーク賛成派です。現場仕事の身としては道路空く、電車空くでいいことずくめなのでもっと多くの会社がそうするべき。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 1,
#   'sample_index': 13,
#   'target': 'テレワーク',
#   'sentence': '夫のテレワークに専業主婦の3割が反対って反対されてる夫ってうちはテレワーク大歓迎だけどなぁ。',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 1,
#   'sample_index': 14,
#   'target': 'テレワーク',
#   'sentence': '時差通勤には賛成ですがテレワークは3年やってもういいかな感ある。ヒトにもよるだろうが根がクズなので、際限なくサボるし、太るし。のんびりしたいからたまには家からーという緩い感じはいいが常態ではマズい個人的には社会復帰できなくなるテレワーク勢ってのが今後少なからず出ると思います',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 15,
#   'target': 'テレワーク',
#   'sentence': 'コロナになってよかったのは、何故か夫の仕事に余裕が出来たこと。テレワークで通勤時間がなくなったことだけでも大きかった。テレワークに100%賛成とは思わないけど、自分たちの都合だけ考えたら80%位は賛成。コロナ終わってもテレワークが定着するといなぁ。',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 1,
#   'target': 'テレワーク',
#   'sentence': '批判あると思うんですが、個人的には事務の方のテレワークには賛成しかねます。補助で社員としかやり取りしないのであればまだわかるんですが、そうじゃないのであればむしろ社員じゃなくて外注でいいんじゃないかと思います。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 2,
#   'target': 'テレワーク',
#   'sentence': '昨日テレワークだったせいか、今日は気分的に日曜な感じ。テレワークは嫌いじゃないけど、これがずーっと1か月間続くと思うと、やっぱりしんどいな。2日ですらちょっと飽きた感じ。慣れたらラクだけど、やっぱり外に出て動いた方がいい。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 3,
#   'target': 'テレワーク',
#   'sentence': '現代社会の課題についての議論は論点がナンセンスなものが多い。テレワークすべきか、出勤すべきかの議論ではなくてテレワークでも出勤でも好きな時に好きな方を選択できる仕組みはどうやったら生まれるのか？という生産的な議論をするべき。AかBではなくてXという解を導き出せ。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 4,
#   'target': 'テレワーク',
#   'sentence': '営業も一緒だと思う…コロナ禍によるテレワーク時代。今後もテレワークに賛成な人は70%でも完全にテレワークしていた人の割合が変わってきた。1年前は30%今は10%に。理由の中には孤独感、疎外感に嫌気も。得意先も直接会っての商談がやりやすいのは一緒。やはり人の繋がりは大事ですよね！',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 7,
#   'target': 'テレワーク',
#   'sentence': 'テレワーク賛成派と反対派の意見は結構感情的になってて解決するのが難しそうな印象',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 9,
#   'target': 'テレワーク',
#   'sentence': '私はテレワーク賛成派なんだよね。自分がテレワークできない仕事だから羨ましいのもあるが、通勤の時間を家事に充てられたりできるのはデカいし、通勤電車のストレスがなくなるのもデカい。始業前から体力削られてるからね',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 10,
#   'target': 'テレワーク',
#   'sentence': '昨日からテレワークがトレンド入りしていており、なんでかと思えばコロナ5類になった影響でテレワークを廃止する企業が出てきたとのことみたいですね。個人的にテレワークがスタンダードに賛成ですが、・新卒・新規事業の「2新（今作った）」は対面がいいなと思ってます。あとはもう好みですね。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 11,
#   'target': 'テレワーク',
#   'sentence': '職場のテレワーク反対派の人間が同僚に「早く出社したいんじゃないですか！？」と騒いでいたものの、「ケースバイケースですよね」と切り替えされて絶句してた。ちなみに、我が職場ではテレワーク賛成派が五割超え、常時テレワークでOK派が三割だそうです。はてさて、どうなることやら…',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 12,
#   'target': 'テレワーク',
#   'sentence': '係長連中が頑なにテレワーク阻止してるのが不合理な点は部長も賛成してくれたのでそこは助かる。何のためにパスワードがあるんだあほんだら。我が社でテレワーク認めないのうちらの現場だけじゃん。お客様対応以外は家で記録や資料作成させろ！委託先は全員持ってて私らは業務用スマホ無いのも変だよ。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 13,
#   'target': 'テレワーク',
#   'sentence': '普通の時間の電車が混雑している気がするのだが何となく自粛ムードが影響したのかさっさと家に帰ろうみたいなあとケンカ増えてる気がするそういう意味でテレワーク賛成とする',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 14,
#   'target': 'テレワーク',
#   'sentence': 'テレワーク反対の理由が、なんかこう外に出た方が出社したほうがこんなに良いことがあるよ！ってのならまだわかるんだけど（ぼくは嫌だけど）、実際は「家に居づらいから」「家では集中できないから」みたいな、あなたの家庭の事情を他者に強要しないでもらえますか？なことが多そうで',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 3,
#   'sample_index': 1,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムを導入すると人は働かなくなると懸念されてるけど、人が下手に働くと資源を浪費したり環境破壊につながるから「働かない」ってことはそんなに悪いことではないんじゃないか。月10万程度配ったくらいで働かなくなる人は、欲が少なく浪費しない人間として評価していいのでは。',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 3,
#   'sample_index': 3,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム賛成派だったのだけれどこういう話を聞くと考えなしに賛成もまずいなって思う',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 3,
#   'sample_index': 9,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムに賛成であれ反対であれ、これが宗教に見えるのなら、もっと経済のことを知ったほうがいい。世界の経営者や学者たちがベーシックインカムを口にするのはけっして宗教上の理由からではない。彼らがなぜベーシックインカムが必要というのかよく考えて見てほしい。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 3,
#   'sample_index': 10,
#   'target': 'ベーシックインカム',
#   'sentence': '↓COVID後の世界の不公平を解消するための答えはベーシックインカムだ、と宣伝するWEF。「ベーシックインカム」なんか、安易に賛成したら危険だよ。働かずして収入を得る（不労収入）なんて、本来、あってはならない話。全て無料で提供されるべき、なんて典型的な「甘い餌」',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 3,
#   'sample_index': 11,
#   'target': 'ベーシックインカム',
#   'sentence': '何もベーシックインカムのメリットが思いつかない。全て最低賃金をあげることで解決する気がするんだよな。ベーシックインカム 賛成派の人間！！！ベーシックインカムのメリットを教えてくれ！！！！！',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 3,
#   'sample_index': 12,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムは不公平を緩和するかも知れないけれど、逆に加速させかねない危険もあると僕は思っている。「必要最低限の衣食住」のレベルは一定ではなく社会状況に応じて変化するものだし、「必要最低限」を身の丈にあった幸せと享受するとは限らない。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 3,
#   'sample_index': 14,
#   'target': 'ベーシックインカム',
#   'sentence': 'そもそも鬱の原因や引き起こす物質は分かったらしいから、今後鬱で苦しむ人は改善されていくんだろうな。それでも社会に適応できなかったりコミュ力なさすぎてどうにも働けない人はどうしてもいるから、ベーシックインカムに賛成ではあるのね。でもネット活用して1人ででも稼ぐ方法見つけてほしいな',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 4,
#   'sample_index': 1,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムで働かなくて済む！お金はAIが稼いでくれる！って本気で言ってる人がいたけど、それって資本主義社会の日本だと、限りなく相性が悪いと思うんだが。AIが稼ぐって言っても、具体的にどうやって？馬鹿でも分かるように説明してくれよ',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 4,
#   'sample_index': 2,
#   'target': 'ベーシックインカム',
#   'sentence': 'この定義であれば、私の立場は明確にベーシックインカム反対だ。時限的給付は賛成だが、恒久的であれば意味が違う。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 4,
#   'sample_index': 3,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム賛成一生懸命働いてる人が不公平？そう思うってことは、働きたくないって心の何処かで思ってる証拠では？働きたくないなら休めばいい世間体が気になる？それは自分の問題。自分が世間体気になるから無理して働いて、不公平だからベーシックインカムは辞めろ！って自己中心的',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 4,
#   'sample_index': 6,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム導入で、社会保障費削減か制度が消えるというような懸念があって議論がなかなか進まない。ならば根本の医療費が高過ぎか過剰ではないか、現状の年金制度は今後どうなるのかという議論も併せてしてみてはどうか。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 4,
#   'sample_index': 7,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムについては以前は賛成寄りだったんですが、今は反対寄りの考えになってきました。給付自体は必要だと思うんですが、もしベーシックインカムが実現すると「ほら、金は配ったぞ。後は自分でなんとかしろ」みたいに、行政がめちゃんこ雑になりそうでこわい。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 4,
#   'sample_index': 8,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム賛成です。ベーシックインカムで解決される事がどれだけ沢山あるか。デメリットの方が思い当たらないです。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 4,
#   'sample_index': 10,
#   'target': 'マイナンバーカード',
#   'sentence': 'はあ、なんで迅速な給付ができないのがマイナンバーカードの問題になるわけ。給付行政の失敗を国民のマイナンバーカード取得の問題に論点ずらししている。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 4,
#   'sample_index': 11,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードに保険証を紐付けるのを反対する人達の声が大きいんでしょうね日本人ならメリットしかないのに',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 4,
#   'sample_index': 12,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードもマイナ保険証も便利やし反対してる理由が分かんないです。むちゃ便利ですよ！',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 4,
#   'sample_index': 14,
#   'target': 'マイナンバーカード',
#   'sentence': '暇だからマイナンバーカードの電子証明書の更新に行ってくる！早めの行動！',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 4,
#   'sample_index': 15,
#   'target': 'マイナンバーカード',
#   'sentence': '私、マイナンバーカードに対しては賛成なんだよね。免許証と保険証一緒ならそれと少しの現金だけ持ってればいいし。ポイントカードは持ってないから。電子ポイントカードはあるけど。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 5,
#   'sample_index': 1,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードと公金受取口座登録を増やしたいのであれば、「給付金をマイナンバーカード経由で公金受取口座にだけ支払います」ってのをやればいいと思う。謎のマイナンバーカード普及キャンペーンにお金使うよりはよっぽど効果的だし、本来の使い方だと思う。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 5,
#   'sample_index': 2,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードに否定的な意見があるのも承知ですが私は賛成です。情報漏洩などセキュリティ問題は別個に対策を講じるべきです。',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 5,
#   'sample_index': 4,
#   'target': 'マイナンバーカード',
#   'sentence': 'やっと自治体に3回接種が反映されたー。接種証明、マジで簡単に取得できるから、マイナンバーカードある人はこのアプリ使うと良いよ',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 5,
#   'sample_index': 5,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードとマイナンバー制度を混同しているツイートを良く見かけるが、種々の個人情報との紐付けは本来マイナンバーカードが無くても出来る。カードそのものというより公的個人認証制度を普及させたいんだろうけど、マイナンバーカード普及というと論点がずれる気がする。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 5,
#   'sample_index': 6,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーとマイナンバーカードの活用に消極的な人達には後暗いものがあると思う。お金との紐づけでお金の可視化がされ、資産との紐づけで財産の可視化がされる。これらを否定する根拠がないないなら賛成すべきはマイナンバーとマイナンバーカードの紐づけの普及促進!!',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 5,
#   'sample_index': 7,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードが自動車運転免許証の機能を持つことは、便利になって賛成なんだけど、だからといって自動車運転免許証を廃することには反対。マイナンバーカードを失くせば、本人確認の手段がなくなってしまうから',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 5,
#   'sample_index': 10,
#   'target': 'マイナンバーカード',
#   'sentence': '今、報ステで、朝日新聞記者が出演し、マイナンバーカードを作れば、免許証、健康保険証、スマホ、銀行口座と紐付けられ利用者にとってメリットが大きいと言っていた。国民は政府に個人情報を握られ、どのような目に合わされるか分からないのに、デメリットは全くないかのような言い振り。大嘘だ。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 5,
#   'sample_index': 11,
#   'target': 'マイナンバーカード',
#   'sentence': '『将来的には国内でもオンライン投票の導入を検討したいと意欲を示しました。オンライン投票の実施にはマイナンバーカードを活用する考えです。』それ、誰が誰に入れたかわかるってことかな。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 5,
#   'sample_index': 13,
#   'target': 'マイナンバーカード',
#   'sentence': '色々言われているマイナンバーカードですが、私は基本的に賛成ですマイナンバーカードによる利便性と情報漏洩のリスクは分けて考える必要があると思いますデジタル通貨もドローンも自動運転もクラウドも情報漏洩のリスクや脆弱性に関する危険性はありますけど、全部否定したら日本だけ取り残されます',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 6,
#   'sample_index': 0,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアを利用した事ない人は安いけど質が低いと勘違いしてる人多いけど ①乗る前にドライバー情報確認（評価の低い車には乗らないも可）②乗る前から金額も決まってる（事前カード決算）③万が一のトラブルは直ぐに運営会社に報告  など結果タクシーより質は高く、消費者にはメリットしかないの',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 6,
#   'sample_index': 2,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアに関しては賛成でも反対でもなかったがライドシェアを日本に取り込む事により性犯罪が増えるという見解があり、反対派になった。これ以上性犯罪を増やしてはいけない。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 6,
#   'sample_index': 3,
#   'target': 'ライドシェア',
#   'sentence': 'アメリカの司法が「ライドシェアは詐欺的な仕組みで正当な賃金を奪い取ってきた」と断定したからライドシェアはもう終わりですよ。もはやライドシェア推進派が好きな「世界ではライドシェアが普通、日本は遅れてる」という論調も通用しません。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 6,
#   'sample_index': 5,
#   'target': 'ライドシェア',
#   'sentence': '僕はライドシェア解禁賛成派ですが決してタクシーを敵視しているわけではありません。以前からタクシー全体のイメチェンが最重要課題だと伝えてきましたが、乗務員だけでなく利用者の理解・協力も必要です。そういう意味でも利用者の選択肢が増えることはいいことだと思っています。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 6,
#   'sample_index': 6,
#   'target': 'ライドシェア',
#   'sentence': 'あなたが自分の仕事を奪われそうになったら黙っていられますか？顔も住所も現在地も分かっていても、事件は未然に防げませんよね？ライドシェアの危険性は交通事故だけでは済まされませんよ？？ライドシェアは安物買いの銭失いにしか過ぎないと思いますけど。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 6,
#   'sample_index': 7,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェア反対署名の件がRTで回ってきた。どうにも日本の場合、ライドシェアによって海外で何が起きたか、ちゃんと分析されないまま、「労働搾取的」であることや「白タク」であることへの批判が先に立っている気がする。（単に賛成ではないです、念のため）',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 6,
#   'sample_index': 9,
#   'target': 'ライドシェア',
#   'sentence': 'タクシー運転手の仕事はこれから無くなるって確実に。時代は変わっていく。気持ちはわかるが、そーゆ時代。そして新しい技術、文化技、発展してくのだよ。白タク、ライドシェア賛成。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 6,
#   'sample_index': 10,
#   'target': 'ライドシェア',
#   'sentence': 'シンガポールはGrabというアプリでタクシーもライドシェアも両方呼べるライドシェアがつかまらなければ、タクシーを呼ぶのでタクシーにもメリットある実際タクシー乗る回数増えたサービス良ければタクシー選ぶし',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 6,
#   'sample_index': 11,
#   'target': 'ライドシェア',
#   'sentence': 'いつもそうだけど、やる事を前提にした議論は無意味。ライドシェアを行った場合に、どのようなメリット・デメリットがあるかを議論すべし！！',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 6,
#   'sample_index': 12,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアについて、経済産業省は推進の立場で、国土交通省は反対の立場のようだが、省庁で意見が別れているのも何となく分かる。ライドシェアが必要とされているケースもあれば、参入させるべきではないケースもあるため、どちらが正しいというものでもないのではと思う。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 6,
#   'sample_index': 13,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアの便利さを知ると、離れられなくなるけど、タクシーはタクシーでメリットがあるので甲乙付けがたい。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 6,
#   'sample_index': 15,
#   'target': 'ライドシェア',
#   'sentence': 'タクシー不足で話題のライドシェアの解禁論ですが、あなたはどう思いますか？(ライドシェアは一般の人が自家用車で有料で人を運ぶこと。現在、日本ではタクシー業界の反対で禁止されている)',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 7,
#   'sample_index': 1,
#   'target': 'ライドシェア',
#   'sentence': '良くも悪くもトヨタがライドシェアをやるって決めたら、日本は一気にライドシェア解禁に動くんだろうな。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 7,
#   'sample_index': 2,
#   'target': 'ライドシェア',
#   'sentence': '何度も言うけど。ワシはライドシェアは賛成派！違法タクシーは大嫌い！！これは変わらん。寧ろ違法タクシーなんか全部滅ぶべきやとさえ思ってる。警察とタクセンも動けよ。癒着してんのかお前ら。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 7,
#   'sample_index': 3,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアの解禁は殆ど費用をかけずに実行できる環境重視策。他国でライドシェアを実際に使った経験からも大多数の人にはメリットしかない。一方で業界の反対やゼロリスク信仰などやらない言い訳もゴマンとある。ライドシェアを解禁しない限りは国の環境重視策などまやかしでしかない。',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 7,
#   'sample_index': 5,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアが今検討されてるけど、導入は賛成派です。ウーバータクシーを主に使ってるけど行き先も事前に指定して言葉の壁を感じ無いし、料金や目的地までの経路も明朗会計で安心ですよね。現在地点に迎えに来てくれるし。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 7,
#   'sample_index': 7,
#   'target': 'ライドシェア',
#   'sentence': 'カスみたいな煽り運転と、暴走老人の運転が話題になってるのにライドシェアなんて賛成できない。事故、高額請求、性被害、勧誘、喧嘩これだけでも簡単に想像つくつか知らない人の車に乗っちゃダメって習ってる',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 7,
#   'sample_index': 8,
#   'target': '選択的夫婦別姓',
#   'sentence': '「自分は結婚したら相手と同じ名字にしたい」と「選択的夫婦別姓に賛成」はダブルスタンダードではなくて普通に両立すること  前者は個人の意思で、後者は他人の意思を尊重することだからです選択的夫婦別姓に賛成か反対かは、他人の意思を尊重するか否か',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 7,
#   'sample_index': 9,
#   'target': '選択的夫婦別姓',
#   'sentence': 'むしろ選択的夫婦別姓に何のメリットがあるんですか？',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 7,
#   'sample_index': 10,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓の反対意見で改姓できる人と結婚すればいいというのを見たけど、改姓できない、したくない人の方が多いよな、現に結婚した男性の95%は改姓していないわけだし、改姓できる男性と結婚できる女性は限りなく少ない',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 7,
#   'sample_index': 12,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓に反対するということは、夫婦の片側、多くは女性に改姓の不便を押し付けておきたいということになるけど、思いやりのある人はそんなことはしないよな、女男どちらも改姓の不便を負わない選択ができる',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 7,
#   'sample_index': 13,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓について、今言われている選択的夫婦別姓のメリットは、職場の通称使用選択を可能にすることを義務化すれば、ほぼ解決できるような気がするので、あえて導入する必要があるのだろうかと思う。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 7,
#   'sample_index': 15,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓なんてリスクだらけですよ。子どもの名字は？兄弟でバラバラの名字になるのか？学校でいじめが起きないか？離婚率の増加に繋がらないか？同氏の人が攻撃されるのではないか？家族を識別できなくならないか？様々な手続きが混乱しないか？リスクに適う利益があるとは思えない。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 8,
#   'sample_index': 0,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓に伴って発生するであろうデメリットを言うたびに、寄ってたかって否定してくるのが気持ちが悪い――メリットとデメリットを明らかにしたうえで、国民の判断を仰ぐべきだろうに。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 8,
#   'sample_index': 2,
#   'target': '選択的夫婦別姓',
#   'sentence': '例えば、「選択的夫婦別姓制」について、ジャーナリズムの役割は、それを推進する立場で報道することではない。反対する立場で論陣を張ることでもない。賛成、反対のどちらの考えに対しても、その利点、問題点を冷静に分析し、報じることである。結論を出すのは読者、視聴者であり、有権者なのだ。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 8,
#   'sample_index': 6,
#   'target': '選択的夫婦別姓',
#   'sentence': '党首討論で与野党の違いがはっきりした論点なので、今回の参院選、ひたすらメディアも選択的夫婦別姓制度の導入を進めるか否か、与党に問い続ければいいし、それだけ論点にして選挙すればいいよ。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 8,
#   'sample_index': 8,
#   'target': '選択的夫婦別姓',
#   'sentence': '正直、選択的夫婦別姓制度は、それを声高に推進しようとする連中が、こうやってあまりに不誠実で身勝手だから、とてもじゃないけど賛成する気にならんのだよ。自分のこと、自分の権利を喚くばっかりで、子供の姓をどうするのかとかおよそ真剣に問題点を考えようとしない姿勢、全く信用におけない。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 8,
#   'sample_index': 13,
#   'target': '選択的夫婦別姓',
#   'sentence': 'そもそも「選択的夫婦別姓が“ないから”結婚できない夫婦」はいても、「選択的夫婦別姓“あるから”結婚できない夫婦」はいないんだよね。それ時点で、この婚姻率低下&少子化の問題を抱える社会には大きなメリットだと思うなぁ',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 9,
#   'sample_index': 0,
#   'target': '選択的夫婦別姓',
#   'sentence': '「選択的夫婦別姓」を私が素直に賛成できないのは、それで生まれた子ども自身が「選択するわけではない」から。親の決めた家族の形に従うことになるから。本人達はそれでよくても、周囲がそれに伴う負担を強いられることになる。難色を示し反対意見を述べただけで総攻撃になる様も危険性を感じる。',
#   'predicted_label': 1,
#   'correct_label': 2}]
