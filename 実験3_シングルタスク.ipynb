# %% [markdown]
# <a href="https://colab.research.google.com/github/Mizuko821/master_thesis/blob/main/%E5%AE%9F%E9%A8%933_%E3%82%B7%E3%83%B3%E3%82%B0%E3%83%AB%E3%82%BF%E3%82%B9%E3%82%AF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##環境
# Google Colabratory
# ランタイム:GPU（V100）を使用

# %%
# !pip install transformers torch
# !pip install accelerate -U
# !pip install fugashi ipadic

# %%
import os
import json
import re
import pandas as pd
from transformers import AutoTokenizer, BertTokenizer, BertPreTrainedModel, BertModel, AdamW, get_linear_schedule_with_warmup, TrainingArguments
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split, RandomSampler, SequentialSampler
from torch.optim import AdamW
import matplotlib.pyplot as plt
from torch import nn
from transformers.modeling_outputs import SequenceClassifierOutput
from sklearn.manifold import TSNE
import numpy as np
from typing import Tuple
from sklearn.metrics import confusion_matrix
import seaborn as sns
import random
from sklearn.metrics import f1_score, classification_report

# %%
# デバイスの設定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def set_seed(seed_value):
    """Set seed for reproducibility.
    """
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)

set_seed(42)

# %%
#Twitterデータセットへのファイルのパスを設定する
tweet_path = "パスを入力する"

# %%
# CSVファイルを読み込む
df = pd.read_csv(tweet_path)
df.head()
# Out:
#     target                                           sentence  polarity
# 0  インボイス制度  フリーランスや、フリーランスへの親近感が強い方が多めのタイムライン構成なので、インボイス制度...  positive
# 1  インボイス制度  個人的な意見だが徴税制度がすべて悪とは思ってない。インボイス制度はわけのわからん軽減率より分...  positive
# 2  インボイス制度  こんな状況にもかかわらずインボイス制度賛成というのは理解が難しいです。大企業ではなく、個人事...  negative
# 3  インボイス制度  インボイス制度はそもそも反対なのだが、まず前提として、あらゆる手続きの負荷は簡便であることを...  negative
# 4  インボイス制度  インボイス制度何が何でも反対！の人が多いけど消費税払ってるちっさい会社の立場としてはなんでそ...  positive

# %%
# 改行コードを削除
df['sentence'] = df['sentence'].apply(lambda x: re.sub(r'\r?\n', '', x))
df['sentence']
# Out:
# 0      フリーランスや、フリーランスへの親近感が強い方が多めのタイムライン構成なので、インボイス制度...
# 1      個人的な意見だが徴税制度がすべて悪とは思ってない。インボイス制度はわけのわからん軽減率より分...
# 2      こんな状況にもかかわらずインボイス制度賛成というのは理解が難しいです。大企業ではなく、個人事...
# 3      インボイス制度はそもそも反対なのだが、まず前提として、あらゆる手続きの負荷は簡便であることを...
# 4      インボイス制度何が何でも反対！の人が多いけど消費税払ってるちっさい会社の立場としてはなんでそ...
#                              ...
# 140    選択的夫婦別姓のメリットは・姓を理由として結婚しなかった人たちが結婚に踏み切れる・親子での姓...
# 141    そもそも「選択的夫婦別姓が“ないから”結婚できない夫婦」はいても、「選択的夫婦別姓“あるから...
# 142    選択的夫婦別姓ってノーリスクでリターンしかないと思ってたけど、別姓にしなかった場合に「同姓に...
# 143    選択的夫婦別姓の問題点について考えてみたが、戸籍とかその辺の法律改正含むし、大混乱になる可能...
# 144    「選択的夫婦別姓」を私が素直に賛成できないのは、それで生まれた子ども自身が「選択するわけでは...
# Name: sentence, Length: 145, dtype: object

# %%
# 極性ラベルを数字にマッピング
label_mapping = {"positive": 0, "neutral": 1, "negative": 2}
df["pol_labels"] = df["polarity"].map(label_mapping)

# %%
num_pol_labels = 3
print(num_pol_labels)
# Out:
# 3

# %% [markdown]
# ### モデル定義

# %%
class SingleTaskModel(BertPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.num_labels = config.num_labels
        self.config = config

        self.bert = BertModel(config)

        classifier_dropout = (
            config.classifier_dropout if config.classifier_dropout is not None \
                else config.hidden_dropout_prob
        )

        # 極性分類用のネットワーク
        self.pol_dropout = nn.Dropout(classifier_dropout)
        self.pol_layer1 = nn.Linear(config.hidden_size, config.hidden_size)
        self.pol_activation1 = nn.ReLU()
        self.pol_layer2 = nn.Linear(config.hidden_size, config.hidden_size)
        self.pol_activation2 = nn.ReLU()
        self.pol_classifier = nn.Linear(config.hidden_size, config.num_labels)

        self.post_init()

    def forward(self, input_ids=None, attention_mask=None, token_type_ids=None, pol_labels=None, **kwargs):
        outputs = self.bert(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids, **kwargs)
        pooled_output = outputs[1]
        pooled_output = self.pol_dropout(pooled_output)

        # 感情分類のロジット
        pol_out = self.pol_activation1(self.pol_layer1(pooled_output))
        pol_out = self.pol_activation2(self.pol_layer2(pol_out))
        pol_logits = self.pol_classifier(pol_out)

        return {
            "pol_logits": pol_logits,
            "hidden_states": outputs.hidden_states,
            "attentions": outputs.attentions,
            "pooler_output":outputs.pooler_output
        }

# %%
# 1. モデルアーキテクチャの初期化
#tokenizerとmodelのインスタンス化
modelName = 'cl-tohoku/bert-base-japanese-whole-word-masking'
tokenizer =  AutoTokenizer.from_pretrained(modelName)
model = SingleTaskModel.from_pretrained(modelName, num_labels=num_pol_labels).to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/110 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/479 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/258k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of SingleTaskModel were not initialized from the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking and are newly initialized: ['pol_classifier.weight', 'pol_layer1.bias', 'pol_layer2.bias', 'pol_layer2.weight', 'pol_classifier.bias', 'pol_layer1.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#保存された状態辞書のロード
model_path = "実験1で学習したsingleモデルへのパスを入力する"
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
# モデルのコピーを複数作成
models = [copy.deepcopy(model) for _ in range(6)]
model1, model2, model3, model4, model5, model6 = models

# %% [markdown]
# ###モデル実装（クロスバリデーション）

# %%
class TextDataset(Dataset):
    def __init__(self, target, sentence, pol_labels):
        self.target = target.values
        self.sentence = sentence.values
        self.pol_labels = pol_labels.values

    def __len__(self):
        return len(self.target)

    def __getitem__(self, idx):
        return self.target[idx], self.sentence[idx], torch.tensor(self.pol_labels[idx], dtype=torch.long)

# %%
# ターゲットリストの定義（リスト内の要素間にカンマが足りないのを修正）
targets = ['インボイス制度', 'テレワーク', 'ベーシックインカム', 'マイナンバーカード', 'ライドシェア', '選択的夫婦別姓']

# データフレームを分割する関数を定義
def split_df(df, train_targets, val_target, test_target):
    train_df = df[df["target"].isin(train_targets)]
    val_df = df[df["target"] == val_target]
    test_df = df[df["target"] == test_target]
    return train_df, val_df, test_df

# 各分割パターンに対するデータセットを作成
dataloader = {}

# DataLoaderのパラメータ設定
batch_size = 8

# %%
# 各分割パターンに対するデータセットを作成
dfset = {}
dataloader = {}

# %%
for i in range(len(targets)):
    # 分割するターゲットを選択
    train_targets = targets[i:] + targets[:i]
    val_target = train_targets[-2]
    test_target = train_targets[-1]

    # データセットを分割
    train_df, val_df, test_df = split_df(df, train_targets[:-2], val_target, test_target)

    # 分割したデータセットを辞書に保存
    dfset[f'train_df{i+1}'] = train_df
    dfset[f'val_df{i+1}'] = val_df
    dfset[f'test_df{i+1}'] = test_df

    train_dataset = TextDataset(pd.Series(train_df["target"]), pd.Series(train_df["sentence"]), pd.Series(train_df["pol_labels"]))
    val_dataset = TextDataset(pd.Series(val_df["target"]), pd.Series(val_df["sentence"]), pd.Series(val_df["pol_labels"]))
    test_dataset = TextDataset(pd.Series(test_df["target"]), pd.Series(test_df["sentence"]), pd.Series(test_df["pol_labels"]))

    # テスト用データローダー
    train_tweetloader = DataLoader(train_dataset, batch_size=batch_size)
    val_tweetloader = DataLoader(val_dataset, batch_size=batch_size)
    test_tweetloader = DataLoader(test_dataset, batch_size=batch_size)

    # 分割したデータセットを辞書に保存
    dataloader[f'train_tweetloader{i+1}'] = train_tweetloader
    dataloader[f'val_tweetloader{i+1}'] = val_tweetloader
    dataloader[f'test_tweetloader{i+1}'] = test_tweetloader

# %% [markdown]
# ### 途中経過を表示する

# %%
# テスト用の関数before
def modeltest(model, dataloader):
  model.eval()
  total = len(dataloader.dataset)
  len_dataloder = len(dataloader)
  pol_correct = 0
  total_loss = 0 #追加
  with torch.no_grad():
    for target, sentence, pol_labels in dataloader:
      pol_labels = pol_labels.to(device)
      input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
      pred = model(**input)

      pred_pol_labels = pred["pol_logits"].argmax(dim=1)
      pol_correct += (pred_pol_labels == pol_labels).sum().item()

      pol_loss = loss_fct(pred["pol_logits"], pol_labels)
      loss = pol_loss
      total_loss += loss.item()

      # F1スコアの計算
      pol_f1 = f1_score(pol_labels.cpu(), pred_pol_labels.cpu(), average='macro')

  return pol_correct/total, total_loss/len_dataloder, pol_f1

# %%
# 途中経過の表示
def reportProgress(model, dataloader, pol_labels):
  model.eval()
  pol_acc, val_loss, pol_f1= modeltest(model, dataloader)
  val_losslist.append(val_loss)
  pol_acclist.append(pol_acc)
  pol_f1list.append(pol_f1)
  print("epoch[%d/%d] trainLoss=%f, validLoss=%f, pol_acc=%.2f%%, pol_f1=%.4f" % (epoch+1, num_epoch, train_loss/iter, val_loss, pol_acc*100, pol_f1))
  model.train()

# %% [markdown]
# ###モデル実行

# %%
# 学習用の設定
num_epoch = 10 #デフォルトのepoch数
loss_fct = nn.CrossEntropyLoss()
criterion = nn.CrossEntropyLoss() # 損失関数はクロスエントロピー
train_losslist = []
val_losslist = []
pol_acclist = []
category_acclist = []
pol_f1list = []
category_f1list = []

accuracy_set = []
f1_set = []

# 誤った予測とその詳細を記録するリスト
incorrect_polarity_samples = []

# %% [markdown]
# #### クロスバリデーション1

# %%
#モデルの重みを保存するフォルダを設定する
model_save = "保存先のファイルへのパスを設定する"

# %%
#学習1回目
model1.train()
optimizer = torch.optim.RMSprop(model1.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(dataloader["train_tweetloader1"], 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = model1(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(model1, dataloader["val_tweetloader1"], pol_labels)
    torch.save(model1.state_dict(), model_save+f"model_epoch_{epoch+1}.pth")
# Out:
# epoch[1/10] trainLoss=1.733117, validLoss=1.013942, pol_acc=45.83%, pol_f1=0.4222
# epoch[2/10] trainLoss=0.663017, validLoss=0.924349, pol_acc=50.00%, pol_f1=0.5556
# epoch[3/10] trainLoss=0.367665, validLoss=0.949285, pol_acc=54.17%, pol_f1=0.5556
# epoch[4/10] trainLoss=0.165252, validLoss=0.844235, pol_acc=54.17%, pol_f1=0.5556
# epoch[5/10] trainLoss=0.070389, validLoss=0.873723, pol_acc=54.17%, pol_f1=0.5556
# epoch[6/10] trainLoss=0.062125, validLoss=0.976474, pol_acc=54.17%, pol_f1=0.5556
# epoch[7/10] trainLoss=0.022317, validLoss=0.958441, pol_acc=54.17%, pol_f1=0.5556
# epoch[8/10] trainLoss=0.021145, validLoss=0.889389, pol_acc=58.33%, pol_f1=0.5556
# epoch[9/10] trainLoss=0.013424, validLoss=0.932039, pol_acc=58.33%, pol_f1=0.5556
# epoch[10/10] trainLoss=0.007711, validLoss=0.930426, pol_acc=58.33%, pol_f1=0.5556

# %%
#保存された状態辞書のロード
model_path = "採用するモデルの重みへのパスを入力"
model1.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
#テストデータでの検証

model1.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []
pol_predictions_common, pol_labels_list_common = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(dataloader["test_tweetloader1"]):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = model1(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(dataloader["test_tweetloader1"])
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 1.0296
# Test Pol Accuracy: 0.5833, F1: 0.5564
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.67      0.71         9
#            1       0.33      0.43      0.38         7
#            2       0.62      0.56      0.59         9
#
#     accuracy                           0.56        25
#    macro avg       0.57      0.55      0.56        25
# weighted avg       0.59      0.56      0.57        25

# %% [markdown]
# #### クロスバリデーション2

# %%
num_epoch = "採用するepoch数を入力"

# %%
chack_model = model2
train_tweetloader = dataloader["train_tweetloader2"]
val_tweetloader = dataloader["val_tweetloader2"]
test_tweetloader = dataloader["test_tweetloader2"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/3] trainLoss=1.634800, validLoss=0.912824, pol_acc=44.00%, pol_f1=1.0000
# epoch[2/3] trainLoss=0.573707, validLoss=1.105571, pol_acc=52.00%, pol_f1=1.0000
# epoch[3/3] trainLoss=0.333455, validLoss=1.247309, pol_acc=44.00%, pol_f1=1.0000

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 1.0732
# Test Pol Accuracy: 0.5417, F1: 0.5425
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82         7
#            1       0.50      0.25      0.33         8
#            2       0.44      0.50      0.47         8
#
#     accuracy                           0.57        23
#    macro avg       0.55      0.58      0.54        23
# weighted avg       0.54      0.57      0.53        23

# %% [markdown]
# #### クロスバリデーション3

# %%
chack_model = model3
train_tweetloader = dataloader["train_tweetloader3"]
val_tweetloader = dataloader["val_tweetloader3"]
test_tweetloader = dataloader["test_tweetloader3"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/3] trainLoss=1.709421, validLoss=1.488973, pol_acc=52.17%, pol_f1=0.4571
# epoch[2/3] trainLoss=0.605366, validLoss=0.936288, pol_acc=60.87%, pol_f1=0.8222
# epoch[3/3] trainLoss=0.332061, validLoss=0.970010, pol_acc=56.52%, pol_f1=0.8222

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 1.0666
# Test Pol Accuracy: 0.6250, F1: 0.5924
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57        10
#            1       0.50      0.50      0.50         6
#            2       0.75      0.67      0.71         9
#
#     accuracy                           0.60        25
#    macro avg       0.60      0.59      0.59        25
# weighted avg       0.61      0.60      0.60        25

# %% [markdown]
# #### クロスバリデーション4

# %%
chack_model = model4
train_tweetloader = dataloader["train_tweetloader4"]
val_tweetloader = dataloader["val_tweetloader4"]
test_tweetloader = dataloader["test_tweetloader4"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/3] trainLoss=1.870319, validLoss=1.185977, pol_acc=36.00%, pol_f1=1.0000
# epoch[2/3] trainLoss=0.735131, validLoss=1.060876, pol_acc=40.00%, pol_f1=1.0000
# epoch[3/3] trainLoss=0.355140, validLoss=1.119426, pol_acc=48.00%, pol_f1=1.0000

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 0.7610
# Test Pol Accuracy: 0.7083, F1: 0.6714
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71         8
#            1       0.67      0.50      0.57         8
#            2       0.70      0.78      0.74         9
#
#     accuracy                           0.68        25
#    macro avg       0.68      0.68      0.67        25
# weighted avg       0.68      0.68      0.67        25

# %% [markdown]
# #### クロスバリデーション5

# %%
chack_model = model5
train_tweetloader = dataloader["train_tweetloader5"]
val_tweetloader = dataloader["val_tweetloader5"]
test_tweetloader = dataloader["test_tweetloader5"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/3] trainLoss=1.794743, validLoss=0.788057, pol_acc=64.00%, pol_f1=1.0000
# epoch[2/3] trainLoss=0.594949, validLoss=0.631813, pol_acc=60.00%, pol_f1=1.0000
# epoch[3/3] trainLoss=0.275805, validLoss=0.588994, pol_acc=60.00%, pol_f1=1.0000

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 1.6939
# Test Pol Accuracy: 0.5417, F1: 0.5681
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56         9
#            1       0.67      0.44      0.53         9
#            2       0.50      0.80      0.62         5
#
#     accuracy                           0.57        23
#    macro avg       0.57      0.60      0.57        23
# weighted avg       0.59      0.57      0.56        23

# %% [markdown]
# #### クロスバリデーション6

# %%
chack_model = model6
train_tweetloader = dataloader["train_tweetloader6"]
val_tweetloader = dataloader["val_tweetloader6"]
test_tweetloader = dataloader["test_tweetloader6"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/3] trainLoss=1.633998, validLoss=1.603992, pol_acc=21.74%, pol_f1=0.2000
# epoch[2/3] trainLoss=0.725780, validLoss=1.403067, pol_acc=52.17%, pol_f1=0.3556
# epoch[3/3] trainLoss=0.330033, validLoss=1.354892, pol_acc=65.22%, pol_f1=0.4444

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 0.8128
# Test Pol Accuracy: 0.5833, F1: 0.5278
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         8
#            1       0.50      0.70      0.58        10
#            2       0.50      0.17      0.25         6
#
#     accuracy                           0.58        24
#    macro avg       0.58      0.54      0.53        24
# weighted avg       0.58      0.58      0.56        24

# %% [markdown]
# ### 結果

# %%
# 結果の出力
print("Test Pol Accuracy:" + str(np.mean(accuracy_set)))
print("Test Pol F1:" + str(np.mean(f1_set)))
# Out:
# Test Pol Accuracy:0.5972222222222222
# Test Pol F1:0.5764244121700263

# %% [markdown]
# ### 不正解の事例

# %%
len(incorrect_polarity_samples)
# Out:
# 59

# %%
incorrect_polarity_samples
# Out:
# [{'batch_index': 0,
#   'sample_index': 0,
#   'target': '選択的夫婦別姓',
#   'sentence': '「自分は結婚したら相手と同じ名字にしたい」と「選択的夫婦別姓に賛成」はダブルスタンダードではなくて普通に両立すること  前者は個人の意思で、後者は他人の意思を尊重することだからです選択的夫婦別姓に賛成か反対かは、他人の意思を尊重するか否か',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 1,
#   'target': '選択的夫婦別姓',
#   'sentence': 'むしろ選択的夫婦別姓に何のメリットがあるんですか？',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 2,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓の反対意見で改姓できる人と結婚すればいいというのを見たけど、改姓できない、したくない人の方が多いよな、現に結婚した男性の95%は改姓していないわけだし、改姓できる男性と結婚できる女性は限りなく少ない',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 5,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓について、今言われている選択的夫婦別姓のメリットは、職場の通称使用選択を可能にすることを義務化すれば、ほぼ解決できるような気がするので、あえて導入する必要があるのだろうかと思う。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 2,
#   'target': '選択的夫婦別姓',
#   'sentence': '例えば、「選択的夫婦別姓制」について、ジャーナリズムの役割は、それを推進する立場で報道することではない。反対する立場で論陣を張ることでもない。賛成、反対のどちらの考えに対しても、その利点、問題点を冷静に分析し、報じることである。結論を出すのは読者、視聴者であり、有権者なのだ。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 6,
#   'target': '選択的夫婦別姓',
#   'sentence': '党首討論で与野党の違いがはっきりした論点なので、今回の参院選、ひたすらメディアも選択的夫婦別姓制度の導入を進めるか否か、与党に問い続ければいいし、それだけ論点にして選挙すればいいよ。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 0,
#   'target': '選択的夫婦別姓',
#   'sentence': '正直、選択的夫婦別姓制度は、それを声高に推進しようとする連中が、こうやってあまりに不誠実で身勝手だから、とてもじゃないけど賛成する気にならんのだよ。自分のこと、自分の権利を喚くばっかりで、子供の姓をどうするのかとかおよそ真剣に問題点を考えようとしない姿勢、全く信用におけない。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 1,
#   'target': '選択的夫婦別姓',
#   'sentence': 'Wikipediaの夫婦別姓のページでは、選択的夫婦別姓に賛成・反対の団体がよくまとまっている。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 5,
#   'target': '選択的夫婦別姓',
#   'sentence': 'そもそも「選択的夫婦別姓が“ないから”結婚できない夫婦」はいても、「選択的夫婦別姓“あるから”結婚できない夫婦」はいないんだよね。それ時点で、この婚姻率低下&少子化の問題を抱える社会には大きなメリットだと思うなぁ',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 6,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓ってノーリスクでリターンしかないと思ってたけど、別姓にしなかった場合に「同姓にするなんて遅れてる」とか言われることが予測できるのかなんでわざわざ反対までするのか疑問だったがこれは困ったな',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 7,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓の問題点について考えてみたが、戸籍とかその辺の法律改正含むし、大混乱になる可能性秘めてるんだよな。メリットばっかり言ってるけどデメリットもあると思う。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 3,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度はそもそも反対なのだが、まず前提として、あらゆる手続きの負荷は簡便であることを目指すべき、なぜなら多くの人類は事務能力がそれほどないから、事務能力は結構特殊能力、人間のリソースは限られている、仕組みで限られたリソースの可動域を広げるべき、と思っているのが少数なのか？',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 5,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度、益税の観点から真っ向に分かれる意見。片方を鵜呑みにしてはいけないのだなぁ。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 7,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度の問題を所謂左翼・リベラル運動に結びつけたがる人が賛成派にも反対派にもいるけど、そういうのにはついていけないしインボイスとは関係がない。インボイスの問題はその他の政治イデオロギーとは関係のない、あくまでも事業者の税負担・事務負担と生活・経営の問題でしかない。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 1,
#   'target': 'インボイス制度',
#   'sentence': '【お金の話題：インボイス制度】インボイス制度に賛成か反対かは個々人の意見なのでどちらでも良いと思います。ただ、自分の納税負担を相手に押し付ければ良いという考え方は良くない。SNSやネットニュースの「過激な演出」に参加しちゃダメ！',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 2,
#   'target': 'インボイス制度',
#   'sentence': '2022年の参院選で野党共闘爆発です。その暁にはインボイス制度廃止に追い込もう！廃止にしないとコンビニや個人商店の飲食店もインボイス制度の餌食になります。野党共闘積極応援します。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 3,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度さっさと廃止しろよ。インボイス廃止反対派の人たち何が良くて賛成してんの？',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 5,
#   'target': 'インボイス制度',
#   'sentence': '事業者支援、インボイス制度、消費税そのもの論点全てごっちゃにするの辞めてもらっていいですかのお気持ち',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 6,
#   'target': 'インボイス制度',
#   'sentence': '個人事業主、フリーランスに負担のかかる「インボイス制度」。いまいちよく分からないので反対とか賛成もできないが。どうなんだろ？',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 3,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度廃止に賛同・署名しました。来週１６日、財務省に届けてくださるそうです。ちょうどさっき、国会でもインボイス制度に触れていました。コロナ禍で大打撃を受けたアーティストや職人・技術者をさらに廃業へと追い込む悪制。若手の未来がなくなれば、業界の未来も無くなります。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 4,
#   'target': 'インボイス制度',
#   'sentence': '「インボイス制度はどちらかといえば反対だが、反対派が嫌いだから賛成」みたいな人Twitterにいっぱいいたけど、それを繰り返している気がする。自分の意思決定が自分が嫌いな人に左右されているってなんだか不健全な気がするよ。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 0,
#   'target': 'テレワーク',
#   'sentence': 'テレワークは確かに楽です。通勤時間が0になるのは非常に大きいです。しかし、自宅という、全てから開放される安全地帯が仕事に侵食されるというデメリットもあります。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 1,
#   'target': 'テレワーク',
#   'sentence': 'テレワーク、完全になくなったわけではないけど出社推奨されてる感が…。テレワークにデメリット(業務遅延とかコミュニケーション不足とか…)があるからみたいなんですが…おかしいでしょ。その課題解決する方法が本当に出社することなのか？',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 7,
#   'target': 'テレワーク',
#   'sentence': '時差通勤には賛成ですがテレワークは3年やってもういいかな感ある。ヒトにもよるだろうが根がクズなので、際限なくサボるし、太るし。のんびりしたいからたまには家からーという緩い感じはいいが常態ではマズい個人的には社会復帰できなくなるテレワーク勢ってのが今後少なからず出ると思います',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 3,
#   'target': 'テレワーク',
#   'sentence': '昨日テレワークだったせいか、今日は気分的に日曜な感じ。テレワークは嫌いじゃないけど、これがずーっと1か月間続くと思うと、やっぱりしんどいな。2日ですらちょっと飽きた感じ。慣れたらラクだけど、やっぱり外に出て動いた方がいい。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 5,
#   'target': 'テレワーク',
#   'sentence': '営業も一緒だと思う…コロナ禍によるテレワーク時代。今後もテレワークに賛成な人は70%でも完全にテレワークしていた人の割合が変わってきた。1年前は30%今は10%に。理由の中には孤独感、疎外感に嫌気も。得意先も直接会っての商談がやりやすいのは一緒。やはり人の繋がりは大事ですよね！',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 7,
#   'target': 'テレワーク',
#   'sentence': 'うちの会社は居眠り常習犯が多いのでテレワーク廃止は賛成です。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 2,
#   'target': 'テレワーク',
#   'sentence': '私はテレワーク賛成派なんだよね。自分がテレワークできない仕事だから羨ましいのもあるが、通勤の時間を家事に充てられたりできるのはデカいし、通勤電車のストレスがなくなるのもデカい。始業前から体力削られてるからね',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 3,
#   'target': 'テレワーク',
#   'sentence': '昨日からテレワークがトレンド入りしていており、なんでかと思えばコロナ5類になった影響でテレワークを廃止する企業が出てきたとのことみたいですね。個人的にテレワークがスタンダードに賛成ですが、・新卒・新規事業の「2新（今作った）」は対面がいいなと思ってます。あとはもう好みですね。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 4,
#   'target': 'テレワーク',
#   'sentence': '職場のテレワーク反対派の人間が同僚に「早く出社したいんじゃないですか！？」と騒いでいたものの、「ケースバイケースですよね」と切り替えされて絶句してた。ちなみに、我が職場ではテレワーク賛成派が五割超え、常時テレワークでOK派が三割だそうです。はてさて、どうなることやら…',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 5,
#   'target': 'テレワーク',
#   'sentence': '係長連中が頑なにテレワーク阻止してるのが不合理な点は部長も賛成してくれたのでそこは助かる。何のためにパスワードがあるんだあほんだら。我が社でテレワーク認めないのうちらの現場だけじゃん。お客様対応以外は家で記録や資料作成させろ！委託先は全員持ってて私らは業務用スマホ無いのも変だよ。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 1,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムを導入すると人は働かなくなると懸念されてるけど、人が下手に働くと資源を浪費したり環境破壊につながるから「働かない」ってことはそんなに悪いことではないんじゃないか。月10万程度配ったくらいで働かなくなる人は、欲が少なく浪費しない人間として評価していいのでは。',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 3,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム賛成派だったのだけれどこういう話を聞くと考えなしに賛成もまずいなって思う',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 5,
#   'target': 'ベーシックインカム',
#   'sentence': '数年前のベーシックインカムの講演会で現職の公務員で賛成という人がいた。理由は、何かするにも（例えば失業給付などでしょうか）ものすごくコストがかかるということを言っていた。多くの公務員の方は、ベーシックインカムに賛成なのか知りたいですね。反対ならばその理由を知りたいですね',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 0,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム導入に賛成な人の展開する議論とそうでない人の議論がどうしてもギャップが出るのはそれはそれで意味がある事。その意味で、議論始める前にベーシックインカムに賛成か、反対かの態度を鮮明にした方が聞く方からすれば議論の展開を追いやすい。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 1,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムで働かなくて済む！お金はAIが稼いでくれる！って本気で言ってる人がいたけど、それって資本主義社会の日本だと、限りなく相性が悪いと思うんだが。AIが稼ぐって言っても、具体的にどうやって？馬鹿でも分かるように説明してくれよ',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 3,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム賛成一生懸命働いてる人が不公平？そう思うってことは、働きたくないって心の何処かで思ってる証拠では？働きたくないなら休めばいい世間体が気になる？それは自分の問題。自分が世間体気になるから無理して働いて、不公平だからベーシックインカムは辞めろ！って自己中心的',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 6,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム導入で、社会保障費削減か制度が消えるというような懸念があって議論がなかなか進まない。ならば根本の医療費が高過ぎか過剰ではないか、現状の年金制度は今後どうなるのかという議論も併せてしてみてはどうか。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 7,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムについては以前は賛成寄りだったんですが、今は反対寄りの考えになってきました。給付自体は必要だと思うんですが、もしベーシックインカムが実現すると「ほら、金は配ったぞ。後は自分でなんとかしろ」みたいに、行政がめちゃんこ雑になりそうでこわい。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 1,
#   'target': 'マイナンバーカード',
#   'sentence': 'はあ、なんで迅速な給付ができないのがマイナンバーカードの問題になるわけ。給付行政の失敗を国民のマイナンバーカード取得の問題に論点ずらししている。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 2,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードに保険証を紐付けるのを反対する人達の声が大きいんでしょうね日本人ならメリットしかないのに',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 3,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードもマイナ保険証も便利やし反対してる理由が分かんないです。むちゃ便利ですよ！',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 1,
#   'sample_index': 0,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードと公金受取口座登録を増やしたいのであれば、「給付金をマイナンバーカード経由で公金受取口座にだけ支払います」ってのをやればいいと思う。謎のマイナンバーカード普及キャンペーンにお金使うよりはよっぽど効果的だし、本来の使い方だと思う。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 3,
#   'target': 'マイナンバーカード',
#   'sentence': 'やっと自治体に3回接種が反映されたー。接種証明、マジで簡単に取得できるから、マイナンバーカードある人はこのアプリ使うと良いよ',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 4,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードとマイナンバー制度を混同しているツイートを良く見かけるが、種々の個人情報との紐付けは本来マイナンバーカードが無くても出来る。カードそのものというより公的個人認証制度を普及させたいんだろうけど、マイナンバーカード普及というと論点がずれる気がする。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 6,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードが自動車運転免許証の機能を持つことは、便利になって賛成なんだけど、だからといって自動車運転免許証を廃することには反対。マイナンバーカードを失くせば、本人確認の手段がなくなってしまうから',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 1,
#   'sample_index': 7,
#   'target': 'マイナンバーカード',
#   'sentence': '自分は医療費高騰で社会保険料が上がるのを少しでも減らせるマイナンバーカードの導入は必要だと思いますし、ジェネリックの推進と薬品価格の適正化(現在は低過ぎ)も必要だと思います。不要な検査や不適切な処方を患者から要求されても拒否する事も大切だと思います',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 1,
#   'target': 'マイナンバーカード',
#   'sentence': '今、報ステで、朝日新聞記者が出演し、マイナンバーカードを作れば、免許証、健康保険証、スマホ、銀行口座と紐付けられ利用者にとってメリットが大きいと言っていた。国民は政府に個人情報を握られ、どのような目に合わされるか分からないのに、デメリットは全くないかのような言い振り。大嘘だ。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 2,
#   'target': 'マイナンバーカード',
#   'sentence': '『将来的には国内でもオンライン投票の導入を検討したいと意欲を示しました。オンライン投票の実施にはマイナンバーカードを活用する考えです。』それ、誰が誰に入れたかわかるってことかな。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 0,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアを利用した事ない人は安いけど質が低いと勘違いしてる人多いけど ①乗る前にドライバー情報確認（評価の低い車には乗らないも可）②乗る前から金額も決まってる（事前カード決算）③万が一のトラブルは直ぐに運営会社に報告  など結果タクシーより質は高く、消費者にはメリットしかないの',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 2,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアに関しては賛成でも反対でもなかったがライドシェアを日本に取り込む事により性犯罪が増えるという見解があり、反対派になった。これ以上性犯罪を増やしてはいけない。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 3,
#   'target': 'ライドシェア',
#   'sentence': 'アメリカの司法が「ライドシェアは詐欺的な仕組みで正当な賃金を奪い取ってきた」と断定したからライドシェアはもう終わりですよ。もはやライドシェア推進派が好きな「世界ではライドシェアが普通、日本は遅れてる」という論調も通用しません。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 6,
#   'target': 'ライドシェア',
#   'sentence': 'あなたが自分の仕事を奪われそうになったら黙っていられますか？顔も住所も現在地も分かっていても、事件は未然に防げませんよね？ライドシェアの危険性は交通事故だけでは済まされませんよ？？ライドシェアは安物買いの銭失いにしか過ぎないと思いますけど。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 2,
#   'target': 'ライドシェア',
#   'sentence': 'シンガポールはGrabというアプリでタクシーもライドシェアも両方呼べるライドシェアがつかまらなければ、タクシーを呼ぶのでタクシーにもメリットある実際タクシー乗る回数増えたサービス良ければタクシー選ぶし',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 5,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアの便利さを知ると、離れられなくなるけど、タクシーはタクシーでメリットがあるので甲乙付けがたい。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 1,
#   'target': 'ライドシェア',
#   'sentence': '良くも悪くもトヨタがライドシェアをやるって決めたら、日本は一気にライドシェア解禁に動くんだろうな。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 3,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェアの解禁は殆ど費用をかけずに実行できる環境重視策。他国でライドシェアを実際に使った経験からも大多数の人にはメリットしかない。一方で業界の反対やゼロリスク信仰などやらない言い訳もゴマンとある。ライドシェアを解禁しない限りは国の環境重視策などまやかしでしかない。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 4,
#   'target': 'ライドシェア',
#   'sentence': '素人が運転する車にお金を払って乗せてもらうライドシェア導入に反対します',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 7,
#   'target': 'ライドシェア',
#   'sentence': 'カスみたいな煽り運転と、暴走老人の運転が話題になってるのにライドシェアなんて賛成できない。事故、高額請求、性被害、勧誘、喧嘩これだけでも簡単に想像つくつか知らない人の車に乗っちゃダメって習ってる',
#   'predicted_label': 1,
#   'correct_label': 2}]

# %% [markdown]
# ### Confusion Matrix

# %%
# Confusion Matrixの計算
polarity_cm = confusion_matrix(pol_labels_list_common, pol_predictions_common)

# Confusion Matrixの計算後...
plt.figure(figsize=(6, 6))  # サイズ調整

sns.heatmap(polarity_cm, annot=True, fmt="", cmap='Blues', cbar_kws={"shrink": 0.75}, annot_kws={"size": 16})
plt.xlabel('Predicted Polarity', fontsize=20)
plt.ylabel('True Polarity', fontsize=20)
plt.title('Polarity Confusion Matrix', fontsize=20)
plt.tight_layout()
plt.xticks(rotation=90, fontsize=20)
plt.yticks(rotation=0, fontsize=20)
plt.show()
