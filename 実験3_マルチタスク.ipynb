# %% [markdown]
# <a href="https://colab.research.google.com/github/Mizuko821/master_thesis/blob/main/%E5%AE%9F%E9%A8%933_%E3%83%9E%E3%83%AB%E3%83%81%E3%82%BF%E3%82%B9%E3%82%AF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##環境
# Google Colabratory
# ランタイム:GPU（V100）を使用

# %%
# !pip install transformers torch
# !pip install accelerate -U
# !pip install fugashi ipadic
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.25.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: fugashi in /usr/local/lib/python3.10/dist-packages (1.3.0)
# Requirement already satisfied: ipadic in /usr/local/lib/python3.10/dist-packages (1.0.0)

# %%
import os
import json
import re
import pandas as pd
from transformers import AutoTokenizer, BertTokenizer, BertPreTrainedModel, BertModel, AdamW, get_linear_schedule_with_warmup, TrainingArguments
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split, RandomSampler, SequentialSampler
from torch.optim import AdamW
import matplotlib.pyplot as plt
from torch import nn
from transformers.modeling_outputs import SequenceClassifierOutput
from sklearn.manifold import TSNE
import numpy as np
from typing import Tuple
from sklearn.metrics import confusion_matrix
import seaborn as sns
import random
from sklearn.metrics import f1_score, classification_report

# %%
# デバイスの設定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
def set_seed(seed_value):
    """Set seed for reproducibility.
    """
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)

set_seed(42)

# %%
#Twitterデータセットへのファイルのパスを設定する
tweet_path = "パスを入力する"

# %%
# CSVファイルを読み込む
df = pd.read_csv(tweet_path)
df.head()
# Out:
#     target                                           sentence  polarity
# 0  インボイス制度  フリーランスや、フリーランスへの親近感が強い方が多めのタイムライン構成なので、インボイス制度...  positive
# 1  インボイス制度  個人的な意見だが徴税制度がすべて悪とは思ってない。インボイス制度はわけのわからん軽減率より分...  positive
# 2  インボイス制度  こんな状況にもかかわらずインボイス制度賛成というのは理解が難しいです。大企業ではなく、個人事...  negative
# 3  インボイス制度  インボイス制度はそもそも反対なのだが、まず前提として、あらゆる手続きの負荷は簡便であることを...  negative
# 4  インボイス制度  インボイス制度何が何でも反対！の人が多いけど消費税払ってるちっさい会社の立場としてはなんでそ...  positive

# %%
# 改行コードを削除
df['sentence'] = df['sentence'].apply(lambda x: re.sub(r'\r?\n', '', x))
df['sentence']
# Out:
# 0      フリーランスや、フリーランスへの親近感が強い方が多めのタイムライン構成なので、インボイス制度...
# 1      個人的な意見だが徴税制度がすべて悪とは思ってない。インボイス制度はわけのわからん軽減率より分...
# 2      こんな状況にもかかわらずインボイス制度賛成というのは理解が難しいです。大企業ではなく、個人事...
# 3      インボイス制度はそもそも反対なのだが、まず前提として、あらゆる手続きの負荷は簡便であることを...
# 4      インボイス制度何が何でも反対！の人が多いけど消費税払ってるちっさい会社の立場としてはなんでそ...
#                              ...
# 140    選択的夫婦別姓のメリットは・姓を理由として結婚しなかった人たちが結婚に踏み切れる・親子での姓...
# 141    そもそも「選択的夫婦別姓が“ないから”結婚できない夫婦」はいても、「選択的夫婦別姓“あるから...
# 142    選択的夫婦別姓ってノーリスクでリターンしかないと思ってたけど、別姓にしなかった場合に「同姓に...
# 143    選択的夫婦別姓の問題点について考えてみたが、戸籍とかその辺の法律改正含むし、大混乱になる可能...
# 144    「選択的夫婦別姓」を私が素直に賛成できないのは、それで生まれた子ども自身が「選択するわけでは...
# Name: sentence, Length: 145, dtype: object

# %%
# 極性ラベルを数字にマッピング
label_mapping = {"positive": 0, "neutral": 1, "negative": 2}
df["pol_labels"] = df["polarity"].map(label_mapping)

# %%
num_pol_labels = 3
print(num_pol_labels)
# Out:
# 3

# %% [markdown]
# ### モデル定義

# %%
class SingleTaskModel(BertPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.num_labels = config.num_labels
        self.config = config

        self.bert = BertModel(config)

        classifier_dropout = (
            config.classifier_dropout if config.classifier_dropout is not None \
                else config.hidden_dropout_prob
        )

        # 極性分類用のネットワーク
        self.pol_dropout = nn.Dropout(classifier_dropout)
        self.pol_layer1 = nn.Linear(config.hidden_size, config.hidden_size)
        self.pol_activation1 = nn.ReLU()
        self.pol_layer2 = nn.Linear(config.hidden_size, config.hidden_size)
        self.pol_activation2 = nn.ReLU()
        self.pol_classifier = nn.Linear(config.hidden_size, config.num_labels)

        self.post_init()

    def forward(self, input_ids=None, attention_mask=None, token_type_ids=None, pol_labels=None, **kwargs):
        outputs = self.bert(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids, **kwargs)
        pooled_output = outputs[1]
        pooled_output = self.pol_dropout(pooled_output)

        # 感情分類のロジット
        pol_out = self.pol_activation1(self.pol_layer1(pooled_output))
        pol_out = self.pol_activation2(self.pol_layer2(pol_out))
        pol_logits = self.pol_classifier(pol_out)

        return {
            "pol_logits": pol_logits,
            "hidden_states": outputs.hidden_states,
            "attentions": outputs.attentions,
            "pooler_output":outputs.pooler_output
        }

# %%
#モデルアーキテクチャの初期化
#tokenizerとmodelのインスタンス化
modelName = 'cl-tohoku/bert-base-japanese-whole-word-masking'
tokenizer =  AutoTokenizer.from_pretrained(modelName)
model = SingleTaskModel.from_pretrained(modelName, num_labels=num_pol_labels).to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/110 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/479 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/258k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/445M [00:00<?, ?B/s]
# Some weights of SingleTaskModel were not initialized from the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking and are newly initialized: ['pol_layer2.weight', 'pol_classifier.weight', 'pol_layer1.weight', 'pol_layer2.bias', 'pol_layer1.bias', 'pol_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
#必要な重みを選択
sin_model_path = "実験1で学習した感情極性分類のみのモデル（single）へのパスを入力する"
b = torch.load(sin_model_path)
desired_keys = []
# 各要素のキーを列挙
for key in b.keys():
    desired_keys.append(key)

# %%
# 保存された重みファイルをロードする
model_path = "実験1で学習したmultiモデルへのパスを入力する"
saved_weights = torch.load(model_path)

# 指定された重みのみを抽出する
desired_weights = {k: v for k, v in saved_weights.items() if k in desired_keys}

# 必要な重みのみを新しいモデルに適用する
model.load_state_dict(desired_weights, strict=False)

# %%
# モデルのコピーを複数作成
models = [copy.deepcopy(model) for _ in range(6)]
model1, model2, model3, model4, model5, model6 = models

# %% [markdown]
# ###モデル実装（クロスバリデーション）

# %%
class TextDataset(Dataset):
    def __init__(self, target, sentence, pol_labels):
        self.target = target.values
        self.sentence = sentence.values
        self.pol_labels = pol_labels.values

    def __len__(self):
        return len(self.target)

    def __getitem__(self, idx):
        return self.target[idx], self.sentence[idx], torch.tensor(self.pol_labels[idx], dtype=torch.long)

# %%
# ターゲットリストの定義（リスト内の要素間にカンマが足りないのを修正）
targets = ['インボイス制度', 'テレワーク', 'ベーシックインカム', 'マイナンバーカード', 'ライドシェア', '選択的夫婦別姓']

# データフレームを分割する関数を定義
def split_df(df, train_targets, val_target, test_target):
    train_df = df[df["target"].isin(train_targets)]
    val_df = df[df["target"] == val_target]
    test_df = df[df["target"] == test_target]
    return train_df, val_df, test_df

# 各分割パターンに対するデータセットを作成
dataloader = {}

# DataLoaderのパラメータ設定
batch_size = 8

# %%
# 各分割パターンに対するデータセットを作成
dfset = {}
dataloader = {}

# %%
for i in range(len(targets)):
    # 分割するターゲットを選択
    train_targets = targets[i:] + targets[:i]
    val_target = train_targets[-2]
    test_target = train_targets[-1]

    # データセットを分割
    train_df, val_df, test_df = split_df(df, train_targets[:-2], val_target, test_target)

    # 分割したデータセットを辞書に保存
    dfset[f'train_df{i+1}'] = train_df
    dfset[f'val_df{i+1}'] = val_df
    dfset[f'test_df{i+1}'] = test_df

    train_dataset = TextDataset(pd.Series(train_df["target"]), pd.Series(train_df["sentence"]), pd.Series(train_df["pol_labels"]))
    val_dataset = TextDataset(pd.Series(val_df["target"]), pd.Series(val_df["sentence"]), pd.Series(val_df["pol_labels"]))
    test_dataset = TextDataset(pd.Series(test_df["target"]), pd.Series(test_df["sentence"]), pd.Series(test_df["pol_labels"]))

    # テスト用データローダー
    train_tweetloader = DataLoader(train_dataset, batch_size=batch_size)
    val_tweetloader = DataLoader(val_dataset, batch_size=batch_size)
    test_tweetloader = DataLoader(test_dataset, batch_size=batch_size)

    # 分割したデータセットを辞書に保存
    dataloader[f'train_tweetloader{i+1}'] = train_tweetloader
    dataloader[f'val_tweetloader{i+1}'] = val_tweetloader
    dataloader[f'test_tweetloader{i+1}'] = test_tweetloader

# %% [markdown]
# ### 途中経過を表示する

# %%
# テスト用の関数before
def modeltest(model, dataloader):
  model.eval()
  total = len(dataloader.dataset)
  len_dataloder = len(dataloader)
  pol_correct = 0
  total_loss = 0 #追加
  with torch.no_grad():
    for target, sentence, pol_labels in dataloader:
      pol_labels = pol_labels.to(device)
      input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
      pred = model(**input)

      pred_pol_labels = pred["pol_logits"].argmax(dim=1)
      pol_correct += (pred_pol_labels == pol_labels).sum().item()

      pol_loss = loss_fct(pred["pol_logits"], pol_labels)
      loss = pol_loss
      total_loss += loss.item()

      # F1スコアの計算
      pol_f1 = f1_score(pol_labels.cpu(), pred_pol_labels.cpu(), average='macro')

  return pol_correct/total, total_loss/len_dataloder, pol_f1

# %%
# 途中経過の表示
def reportProgress(model, dataloader, pol_labels):
  model.eval()
  pol_acc, val_loss, pol_f1= modeltest(model, dataloader)
  val_losslist.append(val_loss)
  pol_acclist.append(pol_acc)
  pol_f1list.append(pol_f1)
  print("epoch[%d/%d] trainLoss=%f, validLoss=%f, pol_acc=%.2f%%, pol_f1=%.4f" % (epoch+1, num_epoch, train_loss/iter, val_loss, pol_acc*100, pol_f1))
  model.train()

# %% [markdown]
# ###モデル実行

# %%
# 学習用の設定
num_epoch = 10 #デフォルトのエポック数
loss_fct = nn.CrossEntropyLoss()
criterion = nn.CrossEntropyLoss() # 損失関数はクロスエントロピー
train_losslist = []
val_losslist = []
pol_acclist = []
category_acclist = []
pol_f1list = []
category_f1list = []

accuracy_set = []
f1_set = []

# 誤った予測とその詳細を記録するリスト
incorrect_polarity_samples = []

# %% [markdown]
# #### クロスバリデーション1

# %%
#モデルの重みを保存するフォルダを設定する
model_save = "保存先のファイルへのパスを設定する"

# %%
#学習1回目
model1.train()
optimizer = torch.optim.RMSprop(model1.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(dataloader["train_tweetloader1"], 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = model1(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(model1, dataloader["val_tweetloader1"], pol_labels)
    torch.save(model1.state_dict(), model_save+f"model_epoch_{epoch+1}.pth")

# %%
#保存された状態辞書のロード
model_path = "採用するモデルの重みへのパスを入力"
model1.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %%
#テストデータでの検証

model1.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []
pol_predictions_common, pol_labels_list_common = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(dataloader["test_tweetloader1"]):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = model1(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(dataloader["test_tweetloader1"])
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 1.5281
# Test Pol Accuracy: 0.4583, F1: 0.4280
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.57      0.44      0.50         9
#            1       0.36      0.71      0.48         7
#            2       0.50      0.22      0.31         9
#
#     accuracy                           0.44        25
#    macro avg       0.48      0.46      0.43        25
# weighted avg       0.49      0.44      0.42        25

# %% [markdown]
# #### クロスバリデーション2

# %%
num_epoch = "採用するepoch数を入力"

# %%
chack_model = model2
train_tweetloader = dataloader["train_tweetloader2"]
val_tweetloader = dataloader["val_tweetloader2"]
test_tweetloader = dataloader["test_tweetloader2"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/5] trainLoss=3.040725, validLoss=1.240232, pol_acc=40.00%, pol_f1=1.0000
# epoch[2/5] trainLoss=0.808021, validLoss=1.716574, pol_acc=36.00%, pol_f1=0.0000
# epoch[3/5] trainLoss=0.456307, validLoss=1.616129, pol_acc=36.00%, pol_f1=0.0000
# epoch[4/5] trainLoss=0.194952, validLoss=2.424101, pol_acc=32.00%, pol_f1=0.0000
# epoch[5/5] trainLoss=0.114309, validLoss=1.171524, pol_acc=64.00%, pol_f1=1.0000

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 1.1081
# Test Pol Accuracy: 0.4167, F1: 0.4292
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.57      0.53         7
#            1       0.36      0.50      0.42         8
#            2       0.50      0.25      0.33         8
#
#     accuracy                           0.43        23
#    macro avg       0.45      0.44      0.43        23
# weighted avg       0.45      0.43      0.42        23

# %% [markdown]
# #### クロスバリデーション3

# %%
chack_model = model3
train_tweetloader = dataloader["train_tweetloader3"]
val_tweetloader = dataloader["val_tweetloader3"]
test_tweetloader = dataloader["test_tweetloader3"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/5] trainLoss=4.123158, validLoss=2.171587, pol_acc=47.83%, pol_f1=0.4571
# epoch[2/5] trainLoss=0.911656, validLoss=0.935782, pol_acc=69.57%, pol_f1=0.8222
# epoch[3/5] trainLoss=0.228876, validLoss=0.877529, pol_acc=60.87%, pol_f1=0.6746
# epoch[4/5] trainLoss=0.096962, validLoss=0.980737, pol_acc=60.87%, pol_f1=0.6746
# epoch[5/5] trainLoss=0.049725, validLoss=1.320982, pol_acc=60.87%, pol_f1=0.4167

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 1.3312
# Test Pol Accuracy: 0.6250, F1: 0.4643
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.90      0.64        10
#            1       0.00      0.00      0.00         6
#            2       0.86      0.67      0.75         9
#
#     accuracy                           0.60        25
#    macro avg       0.45      0.52      0.46        25
# weighted avg       0.51      0.60      0.53        25
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #### クロスバリデーション4

# %%
chack_model = model4
train_tweetloader = dataloader["train_tweetloader4"]
val_tweetloader = dataloader["val_tweetloader4"]
test_tweetloader = dataloader["test_tweetloader4"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/5] trainLoss=3.408989, validLoss=0.997921, pol_acc=48.00%, pol_f1=1.0000
# epoch[2/5] trainLoss=0.902940, validLoss=1.176046, pol_acc=48.00%, pol_f1=1.0000
# epoch[3/5] trainLoss=0.519605, validLoss=1.224683, pol_acc=56.00%, pol_f1=1.0000
# epoch[4/5] trainLoss=0.320090, validLoss=1.391888, pol_acc=56.00%, pol_f1=1.0000
# epoch[5/5] trainLoss=0.148086, validLoss=1.448025, pol_acc=56.00%, pol_f1=1.0000

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 0.9892
# Test Pol Accuracy: 0.5417, F1: 0.5176
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67         8
#            1       0.33      0.38      0.35         8
#            2       0.67      0.44      0.53         9
#
#     accuracy                           0.52        25
#    macro avg       0.53      0.52      0.52        25
# weighted avg       0.54      0.52      0.52        25

# %% [markdown]
# #### クロスバリデーション5

# %%
chack_model = model5
train_tweetloader = dataloader["train_tweetloader5"]
val_tweetloader = dataloader["val_tweetloader5"]
test_tweetloader = dataloader["test_tweetloader5"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/5] trainLoss=2.429518, validLoss=1.221826, pol_acc=52.00%, pol_f1=0.0000
# epoch[2/5] trainLoss=0.815102, validLoss=0.787942, pol_acc=60.00%, pol_f1=1.0000
# epoch[3/5] trainLoss=0.377815, validLoss=0.697014, pol_acc=60.00%, pol_f1=1.0000
# epoch[4/5] trainLoss=0.159119, validLoss=0.727900, pol_acc=52.00%, pol_f1=1.0000
# epoch[5/5] trainLoss=0.100989, validLoss=0.722203, pol_acc=64.00%, pol_f1=1.0000

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 1.5094
# Test Pol Accuracy: 0.5417, F1: 0.5006
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.56      1.00      0.72         9
#            1       0.50      0.11      0.18         9
#            2       0.60      0.60      0.60         5
#
#     accuracy                           0.57        23
#    macro avg       0.55      0.57      0.50        23
# weighted avg       0.55      0.57      0.48        23

# %% [markdown]
# #### クロスバリデーション6

# %%
chack_model = model6
train_tweetloader = dataloader["train_tweetloader6"]
val_tweetloader = dataloader["val_tweetloader6"]
test_tweetloader = dataloader["test_tweetloader6"]

# %%
#学習本体
chack_model.train()
optimizer = torch.optim.RMSprop(chack_model.parameters(), lr=1e-5) # RMSpropを使う

for epoch in range(num_epoch):  # num_epoch分繰り返す
    train_loss = 0
    for iter, (target, sentence, pol_labels) in enumerate(train_tweetloader, 1):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        optimizer.zero_grad()
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        train_loss += loss.item()
        loss.backward()  # 誤差伝播
        optimizer.step()  # パラメータ更新

    # epochの最後
    reportProgress(chack_model, val_tweetloader, pol_labels)
# Out:
# epoch[1/5] trainLoss=3.498180, validLoss=1.179153, pol_acc=47.83%, pol_f1=0.4190
# epoch[2/5] trainLoss=0.909698, validLoss=1.162057, pol_acc=47.83%, pol_f1=0.3556
# epoch[3/5] trainLoss=0.609246, validLoss=1.154567, pol_acc=56.52%, pol_f1=0.4190
# epoch[4/5] trainLoss=0.323626, validLoss=1.232287, pol_acc=56.52%, pol_f1=0.4190
# epoch[5/5] trainLoss=0.169501, validLoss=1.352446, pol_acc=52.17%, pol_f1=0.4190

# %%
#テストデータでの検証

chack_model.eval()  # モデルを評価モードに変更
total_loss, pol_total_correct, total_samples = 0, 0, len(test_dataset)
pol_predictions, pol_labels_list = [], []

with torch.no_grad():  # 評価中に勾配の計算は不要
    for i, (target, sentence, pol_labels) in enumerate(test_tweetloader):
        pol_labels = pol_labels.to(device)
        input = tokenizer(target, sentence, padding=True, truncation=True, return_tensors='pt').to(device)
        pred = chack_model(**input)
        pol_loss = loss_fct(pred["pol_logits"], pol_labels)
        loss = pol_loss
        total_loss += loss.item()

        # 精度計算
        pred_pol_labels = pred["pol_logits"].argmax(dim=1)
        pol_total_correct += (pred_pol_labels == pol_labels).sum().item()

        # 予測とラベルをリストに追加
        pol_predictions.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list.extend(pol_labels.cpu().numpy())

        # 予測とラベルをコモンリストに追加
        pol_predictions_common.extend(pred_pol_labels.cpu().numpy())
        pol_labels_list_common.extend(pol_labels.cpu().numpy())

        # 予測が誤っていたサンプルのインデックスを記録
        incorrect_pol = (pred_pol_labels != pol_labels).nonzero(as_tuple=True)[0]

        for idx in incorrect_pol:
            incorrect_polarity_samples.append({
                'batch_index': i,
                'sample_index': idx.item(),
                'target': target[idx],  # .item() は適宜変更
                'sentence': sentence[idx],  # 適宜変更
                'predicted_label': pred_pol_labels[idx].item(),
                'correct_label': pol_labels[idx].item()
            })

avg_loss = total_loss / len(test_tweetloader)
pol_accuracy = pol_total_correct / total_samples
# F1スコアの計算
pol_f1 = f1_score(pol_labels_list, pol_predictions, average='macro')
# 分類レポート
pol_report = classification_report(pol_labels_list, pol_predictions)

accuracy_set.append(pol_accuracy)
f1_set.append(pol_f1)

# 結果の出力
print(f"Test Loss: {avg_loss:.4f}")
print(f"Test Pol Accuracy: {pol_accuracy:.4f}, F1: {pol_f1:.4f}")
print("Pol Classification Report:\n", pol_report)
# Out:
# Test Loss: 0.6693
# Test Pol Accuracy: 0.8333, F1: 0.8320
# Pol Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89         8
#            1       1.00      0.60      0.75        10
#            2       0.75      1.00      0.86         6
#
#     accuracy                           0.83        24
#    macro avg       0.85      0.87      0.83        24
# weighted avg       0.87      0.83      0.82        24

# %% [markdown]
# ### 結果

# %%
# 結果の出力
print("Test Pol Accuracy:" + str(np.mean(accuracy_set)))
print("Test Pol F1:" + str(np.mean(f1_set)))
# Out:
# Test Pol Accuracy:0.5694444444444444
# Test Pol F1:0.5286250182947809

# %% [markdown]
# ### 不正解の事例

# %%
len(incorrect_polarity_samples)
# Out:
# 63

# %%
incorrect_polarity_samples
# Out:
# [{'batch_index': 0,
#   'sample_index': 0,
#   'target': '選択的夫婦別姓',
#   'sentence': '「自分は結婚したら相手と同じ名字にしたい」と「選択的夫婦別姓に賛成」はダブルスタンダードではなくて普通に両立すること  前者は個人の意思で、後者は他人の意思を尊重することだからです選択的夫婦別姓に賛成か反対かは、他人の意思を尊重するか否か',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 1,
#   'target': '選択的夫婦別姓',
#   'sentence': 'むしろ選択的夫婦別姓に何のメリットがあるんですか？',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 2,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓の反対意見で改姓できる人と結婚すればいいというのを見たけど、改姓できない、したくない人の方が多いよな、現に結婚した男性の95%は改姓していないわけだし、改姓できる男性と結婚できる女性は限りなく少ない',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 4,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓に反対するということは、夫婦の片側、多くは女性に改姓の不便を押し付けておきたいということになるけど、思いやりのある人はそんなことはしないよな、女男どちらも改姓の不便を負わない選択ができる',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 5,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓について、今言われている選択的夫婦別姓のメリットは、職場の通称使用選択を可能にすることを義務化すれば、ほぼ解決できるような気がするので、あえて導入する必要があるのだろうかと思う。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 7,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓なんてリスクだらけですよ。子どもの名字は？兄弟でバラバラの名字になるのか？学校でいじめが起きないか？離婚率の増加に繋がらないか？同氏の人が攻撃されるのではないか？家族を識別できなくならないか？様々な手続きが混乱しないか？リスクに適う利益があるとは思えない。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 0,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓に伴って発生するであろうデメリットを言うたびに、寄ってたかって否定してくるのが気持ちが悪い――メリットとデメリットを明らかにしたうえで、国民の判断を仰ぐべきだろうに。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 1,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓制の１番の問題点は、子供が両親と同じ姓を名乗ることが不可能になること。次に、両親どちらの姓を名乗らせるかで100%もめること。そして、どちらの姓にするか結論がでないことは確定しています。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 4,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓推進派って、結局現行法に問題点があるって言う割に、選択的夫婦別姓になっても新しい問題が出てくることを無視してるだけ。問題をスライドさせてるだけだから、数年程度ではまだまだ指示されない気がしてきた。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 0,
#   'target': '選択的夫婦別姓',
#   'sentence': '正直、選択的夫婦別姓制度は、それを声高に推進しようとする連中が、こうやってあまりに不誠実で身勝手だから、とてもじゃないけど賛成する気にならんのだよ。自分のこと、自分の権利を喚くばっかりで、子供の姓をどうするのかとかおよそ真剣に問題点を考えようとしない姿勢、全く信用におけない。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 1,
#   'target': '選択的夫婦別姓',
#   'sentence': 'Wikipediaの夫婦別姓のページでは、選択的夫婦別姓に賛成・反対の団体がよくまとまっている。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 4,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓のメリットは・姓を理由として結婚しなかった人たちが結婚に踏み切れる・親子での姓の違いが自然なものとなり、採用でどうこう言われることがなくなるとかをすぐに思い付くし、デメリットは何かある？ってくらいなのに……',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 5,
#   'target': '選択的夫婦別姓',
#   'sentence': 'そもそも「選択的夫婦別姓が“ないから”結婚できない夫婦」はいても、「選択的夫婦別姓“あるから”結婚できない夫婦」はいないんだよね。それ時点で、この婚姻率低下&少子化の問題を抱える社会には大きなメリットだと思うなぁ',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 7,
#   'target': '選択的夫婦別姓',
#   'sentence': '選択的夫婦別姓の問題点について考えてみたが、戸籍とかその辺の法律改正含むし、大混乱になる可能性秘めてるんだよな。メリットばっかり言ってるけどデメリットもあると思う。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 0,
#   'target': 'インボイス制度',
#   'sentence': 'フリーランスや、フリーランスへの親近感が強い方が多めのタイムライン構成なので、インボイス制度に反対する意見をよく見るんだけど、一般企業の経理職を長くやってきた経験からするとインボイス制度わりと賛成なんですよね。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 2,
#   'target': 'インボイス制度',
#   'sentence': 'こんな状況にもかかわらずインボイス制度賛成というのは理解が難しいです。大企業ではなく、個人事業主達の税負担が増え、経費精算が煩わしくなる上に、こんな金の使い方をする現与党に米櫃に手を突っ込ませるのは意味がわからない。「私は税理士雇えるから大丈夫」というレベルの問題じゃないのに。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 3,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度はそもそも反対なのだが、まず前提として、あらゆる手続きの負荷は簡便であることを目指すべき、なぜなら多くの人類は事務能力がそれほどないから、事務能力は結構特殊能力、人間のリソースは限られている、仕組みで限られたリソースの可動域を広げるべき、と思っているのが少数なのか？',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 4,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度何が何でも反対！の人が多いけど消費税払ってるちっさい会社の立場としてはなんでそれ利益になんねん、と思ってるから賛成です。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 7,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度の問題を所謂左翼・リベラル運動に結びつけたがる人が賛成派にも反対派にもいるけど、そういうのにはついていけないしインボイスとは関係がない。インボイスの問題はその他の政治イデオロギーとは関係のない、あくまでも事業者の税負担・事務負担と生活・経営の問題でしかない。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 2,
#   'target': 'インボイス制度',
#   'sentence': '2022年の参院選で野党共闘爆発です。その暁にはインボイス制度廃止に追い込もう！廃止にしないとコンビニや個人商店の飲食店もインボイス制度の餌食になります。野党共闘積極応援します。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 3,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度さっさと廃止しろよ。インボイス廃止反対派の人たち何が良くて賛成してんの？',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 5,
#   'target': 'インボイス制度',
#   'sentence': '事業者支援、インボイス制度、消費税そのもの論点全てごっちゃにするの辞めてもらっていいですかのお気持ち',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 6,
#   'target': 'インボイス制度',
#   'sentence': '個人事業主、フリーランスに負担のかかる「インボイス制度」。いまいちよく分からないので反対とか賛成もできないが。どうなんだろ？',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 1,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度、導入賛成派は『消費税の納税は平等にすべての事業者が行うべき』という主張も、導入反対派の『低所得小規模事業者への減税措置の廃止反対』という主張もどちらにも理はあるので結構難しい説ない？',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 2,
#   'target': 'インボイス制度',
#   'sentence': 'てかインボイス制度に反対してる人達って水増し請求とか実利益を計上してないタイプの小規模事業主も多いだろうなそもそも弱い物いじめとかじゃなくて、計上関連をより正確かつ公平な取引を目指してる意味では俺は賛成だわそれが嫌なら事業辞めて雇用される選択もあるんだし',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 3,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度廃止に賛同・署名しました。来週１６日、財務省に届けてくださるそうです。ちょうどさっき、国会でもインボイス制度に触れていました。コロナ禍で大打撃を受けたアーティストや職人・技術者をさらに廃業へと追い込む悪制。若手の未来がなくなれば、業界の未来も無くなります。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 6,
#   'target': 'インボイス制度',
#   'sentence': 'インボイス制度はどう見ても免税事業者つぶし…少しでもふんだくろうという意志しか感じないし、増税の上にっていうのが…国が国のためだけに税金巻き上げている感じが嫌だな…国民に還元される未来が見えないし、そんな負担ばかり強いるから反対するんだよ…。賛成派って本当に世の中みえてんのかね',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 0,
#   'target': 'テレワーク',
#   'sentence': 'テレワークは確かに楽です。通勤時間が0になるのは非常に大きいです。しかし、自宅という、全てから開放される安全地帯が仕事に侵食されるというデメリットもあります。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 1,
#   'target': 'テレワーク',
#   'sentence': 'テレワーク、完全になくなったわけではないけど出社推奨されてる感が…。テレワークにデメリット(業務遅延とかコミュニケーション不足とか…)があるからみたいなんですが…おかしいでしょ。その課題解決する方法が本当に出社することなのか？',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 7,
#   'target': 'テレワーク',
#   'sentence': '時差通勤には賛成ですがテレワークは3年やってもういいかな感ある。ヒトにもよるだろうが根がクズなので、際限なくサボるし、太るし。のんびりしたいからたまには家からーという緩い感じはいいが常態ではマズい個人的には社会復帰できなくなるテレワーク勢ってのが今後少なからず出ると思います',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 1,
#   'target': 'テレワーク',
#   'sentence': 'リモートワークや在宅での仕事を推奨したりするのは良いとは思うが画面越しではわからないことが多い。だからこれデフォルトになるのは違うと思う。あくまで一つの手段である。ちなみにリモートやテレワークは反対派ではない。むしろ多いに活用してる。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 2,
#   'target': 'テレワーク',
#   'sentence': '批判あると思うんですが、個人的には事務の方のテレワークには賛成しかねます。補助で社員としかやり取りしないのであればまだわかるんですが、そうじゃないのであればむしろ社員じゃなくて外注でいいんじゃないかと思います。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 4,
#   'target': 'テレワーク',
#   'sentence': '現代社会の課題についての議論は論点がナンセンスなものが多い。テレワークすべきか、出勤すべきかの議論ではなくてテレワークでも出勤でも好きな時に好きな方を選択できる仕組みはどうやったら生まれるのか？という生産的な議論をするべき。AかBではなくてXという解を導き出せ。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 5,
#   'target': 'テレワーク',
#   'sentence': '営業も一緒だと思う…コロナ禍によるテレワーク時代。今後もテレワークに賛成な人は70%でも完全にテレワークしていた人の割合が変わってきた。1年前は30%今は10%に。理由の中には孤独感、疎外感に嫌気も。得意先も直接会っての商談がやりやすいのは一緒。やはり人の繋がりは大事ですよね！',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 7,
#   'target': 'テレワーク',
#   'sentence': 'うちの会社は居眠り常習犯が多いのでテレワーク廃止は賛成です。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 4,
#   'target': 'テレワーク',
#   'sentence': '職場のテレワーク反対派の人間が同僚に「早く出社したいんじゃないですか！？」と騒いでいたものの、「ケースバイケースですよね」と切り替えされて絶句してた。ちなみに、我が職場ではテレワーク賛成派が五割超え、常時テレワークでOK派が三割だそうです。はてさて、どうなることやら…',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 7,
#   'target': 'テレワーク',
#   'sentence': 'テレワーク反対の理由が、なんかこう外に出た方が出社したほうがこんなに良いことがあるよ！ってのならまだわかるんだけど（ぼくは嫌だけど）、実際は「家に居づらいから」「家では集中できないから」みたいな、あなたの家庭の事情を他者に強要しないでもらえますか？なことが多そうで',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 2,
#   'target': 'ベーシックインカム',
#   'sentence': '希有な例としては私が居ますかね。私は、私が働くためにベーシックインカムを、一律給付を希望しています。その効果があることは、10万円一律給付の時に経験しましたので信じています。法人税、所得税、消費税、社会保険廃止では赤字で仕事を続けることはできないですけれど、BIならできます。',
#   'predicted_label': 1,
#   'correct_label': 0},
#  {'batch_index': 0,
#   'sample_index': 3,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム賛成派だったのだけれどこういう話を聞くと考えなしに賛成もまずいなって思う',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 1,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムに賛成であれ反対であれ、これが宗教に見えるのなら、もっと経済のことを知ったほうがいい。世界の経営者や学者たちがベーシックインカムを口にするのはけっして宗教上の理由からではない。彼らがなぜベーシックインカムが必要というのかよく考えて見てほしい。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 2,
#   'target': 'ベーシックインカム',
#   'sentence': '↓COVID後の世界の不公平を解消するための答えはベーシックインカムだ、と宣伝するWEF。「ベーシックインカム」なんか、安易に賛成したら危険だよ。働かずして収入を得る（不労収入）なんて、本来、あってはならない話。全て無料で提供されるべき、なんて典型的な「甘い餌」',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 4,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムは不公平を緩和するかも知れないけれど、逆に加速させかねない危険もあると僕は思っている。「必要最低限の衣食住」のレベルは一定ではなく社会状況に応じて変化するものだし、「必要最低限」を身の丈にあった幸せと享受するとは限らない。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 5,
#   'target': 'ベーシックインカム',
#   'sentence': '数年前のベーシックインカムの講演会で現職の公務員で賛成という人がいた。理由は、何かするにも（例えば失業給付などでしょうか）ものすごくコストがかかるということを言っていた。多くの公務員の方は、ベーシックインカムに賛成なのか知りたいですね。反対ならばその理由を知りたいですね',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 7,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムに賛成ですか？',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 0,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム導入に賛成な人の展開する議論とそうでない人の議論がどうしてもギャップが出るのはそれはそれで意味がある事。その意味で、議論始める前にベーシックインカムに賛成か、反対かの態度を鮮明にした方が聞く方からすれば議論の展開を追いやすい。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 2,
#   'target': 'ベーシックインカム',
#   'sentence': 'この定義であれば、私の立場は明確にベーシックインカム反対だ。時限的給付は賛成だが、恒久的であれば意味が違う。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 3,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム賛成一生懸命働いてる人が不公平？そう思うってことは、働きたくないって心の何処かで思ってる証拠では？働きたくないなら休めばいい世間体が気になる？それは自分の問題。自分が世間体気になるから無理して働いて、不公平だからベーシックインカムは辞めろ！って自己中心的',
#   'predicted_label': 2,
#   'correct_label': 0},
#  {'batch_index': 2,
#   'sample_index': 6,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカム導入で、社会保障費削減か制度が消えるというような懸念があって議論がなかなか進まない。ならば根本の医療費が高過ぎか過剰ではないか、現状の年金制度は今後どうなるのかという議論も併せてしてみてはどうか。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 7,
#   'target': 'ベーシックインカム',
#   'sentence': 'ベーシックインカムについては以前は賛成寄りだったんですが、今は反対寄りの考えになってきました。給付自体は必要だと思うんですが、もしベーシックインカムが実現すると「ほら、金は配ったぞ。後は自分でなんとかしろ」みたいに、行政がめちゃんこ雑になりそうでこわい。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 0,
#   'sample_index': 1,
#   'target': 'マイナンバーカード',
#   'sentence': 'はあ、なんで迅速な給付ができないのがマイナンバーカードの問題になるわけ。給付行政の失敗を国民のマイナンバーカード取得の問題に論点ずらししている。',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 4,
#   'target': 'マイナンバーカード',
#   'sentence': '健康保険証の原則廃止。マイナンバーカードに全ての情報を。個人的には紐付けにはメリットデメリットあって。紛失、個人情報漏洩は怖い。保険証も会社代われば変わるし。まだざっくりとした方針で、国を信頼できないってのが1番のネックかな。みんなはどう思う？',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 5,
#   'target': 'マイナンバーカード',
#   'sentence': '暇だからマイナンバーカードの電子証明書の更新に行ってくる！早めの行動！',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 0,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードと公金受取口座登録を増やしたいのであれば、「給付金をマイナンバーカード経由で公金受取口座にだけ支払います」ってのをやればいいと思う。謎のマイナンバーカード普及キャンペーンにお金使うよりはよっぽど効果的だし、本来の使い方だと思う。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 2,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードが身分証明書になるといっても、免許証みたいに番号を控えたり、コピーできるものじゃないのだから、いくらでも悪用できそう。その道のプロなら偽造カードも簡単に作れるじゃないの？これじゃマイナスカードだよ。',
#   'predicted_label': 1,
#   'correct_label': 2},
#  {'batch_index': 1,
#   'sample_index': 3,
#   'target': 'マイナンバーカード',
#   'sentence': 'やっと自治体に3回接種が反映されたー。接種証明、マジで簡単に取得できるから、マイナンバーカードある人はこのアプリ使うと良いよ',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 4,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードとマイナンバー制度を混同しているツイートを良く見かけるが、種々の個人情報との紐付けは本来マイナンバーカードが無くても出来る。カードそのものというより公的個人認証制度を普及させたいんだろうけど、マイナンバーカード普及というと論点がずれる気がする。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 1,
#   'target': 'マイナンバーカード',
#   'sentence': '今、報ステで、朝日新聞記者が出演し、マイナンバーカードを作れば、免許証、健康保険証、スマホ、銀行口座と紐付けられ利用者にとってメリットが大きいと言っていた。国民は政府に個人情報を握られ、どのような目に合わされるか分からないのに、デメリットは全くないかのような言い振り。大嘘だ。',
#   'predicted_label': 0,
#   'correct_label': 2},
#  {'batch_index': 2,
#   'sample_index': 2,
#   'target': 'マイナンバーカード',
#   'sentence': '『将来的には国内でもオンライン投票の導入を検討したいと意欲を示しました。オンライン投票の実施にはマイナンバーカードを活用する考えです。』それ、誰が誰に入れたかわかるってことかな。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 6,
#   'target': 'マイナンバーカード',
#   'sentence': 'マイナンバーカードに反対じゃあないんだけどなあ、僕は。年金をまずちゃんと管理してほしい。あと、銀行口座の管理にマイナンバーが必須になるんだったら、海外在住の日本人にもマイナンバーを発行して欲しい。',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 0,
#   'sample_index': 7,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェア反対署名の件がRTで回ってきた。どうにも日本の場合、ライドシェアによって海外で何が起きたか、ちゃんと分析されないまま、「労働搾取的」であることや「白タク」であることへの批判が先に立っている気がする。（単に賛成ではないです、念のため）',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 1,
#   'sample_index': 6,
#   'target': 'ライドシェア',
#   'sentence': 'タクシーのライドシェアに賛成の立場の方って、タクシーのどこに不満なのかなと？\u3000値段は、安全を担保するために基準がさざめられているし。タクシーの規制緩和で、増車して供給過多になって、その後、減車のされるケースもあります。（例:新潟市内の営業エリア）',
#   'predicted_label': 0,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 0,
#   'target': 'ライドシェア',
#   'sentence': 'ライドシェア賛成反対とかテレビでやってたけど賛成なら使えばええし反対なら使わなければええ。わからんならやめとけ',
#   'predicted_label': 2,
#   'correct_label': 1},
#  {'batch_index': 2,
#   'sample_index': 1,
#   'target': 'ライドシェア',
#   'sentence': '良くも悪くもトヨタがライドシェアをやるって決めたら、日本は一気にライドシェア解禁に動くんだろうな。',
#   'predicted_label': 0,
#   'correct_label': 1}]

# %% [markdown]
# ### Confusion Matrix

# %%
# Confusion Matrixの計算
polarity_cm = confusion_matrix(pol_labels_list_common, pol_predictions_common)

# Confusion Matrixの計算後...
plt.figure(figsize=(6, 6))  # サイズ調整

sns.heatmap(polarity_cm, annot=True, fmt="", cmap='Blues', cbar_kws={"shrink": 0.75}, annot_kws={"size": 16})
plt.xlabel('Predicted Polarity', fontsize=20)
plt.ylabel('True Polarity', fontsize=20)
plt.title('Polarity Confusion Matrix', fontsize=20)
plt.tight_layout()
plt.xticks(rotation=90, fontsize=20)
plt.yticks(rotation=0, fontsize=20)
plt.show()
